# %% [markdown]
# # 2024-2 DSL 정규세션 과제
#
# ## CNN Assignment
#
# - 작성자 : 11기 김현진
# - 과제 제출 기한 : 08.25
#
# ---
# - 이름 : 한은결
# - 기수 : 11기

# %%
# colab 환경에서 학습을 진행하실 분들은 구글드라이브를 연동해주세요
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 코드의 빈칸을 채우는 것 외에 6개의 이론 + 학습 결과 확인 문제가 별도로 존재합니다. 꼼꼼히 확인하여 누락 없이 제출해주세요.

# %% [markdown]
# ### 문제 1.
#
# U-Net과 ResNet 아키텍쳐에서 동시에 등장하는 Skip Connection에 대해 설명해주세요.
# Skip Connection의 간단한 정의와 각각의 모델에서 해당 기법이 왜 사용되는지를 중점으로 설명해주세요.

# %% [markdown]
# [풀이] U-Net과 ResNet에서 Skip Connection은 정보 손실을 방지하고, 학습 성능을 극대화하는 중요한 역할을 합니다. U-Net에서는 주로 공간적 정보의 복원을 돕기 위해 사용되며, ResNet에서는 깊은 네트워크의 안정적인 학습을 돕는 역할을 합니다

# %% [markdown]
# ### 문제 2.
#
# conv layer의 얕은 층과 깊은 층 간에는 feature map이 담고 있는 정보 특성에 trade-off가 존재합니다. 이에 대해 구체적으로 설명해주세요. U-Net은 이를 어떻게 해결하고 있는지 Skip Connection과 연관지어 설명해주세요.

# %% [markdown]
# [풀이] CNN의 얕은 층과 깊은 층 간에는 정보 특성의 trade-off가 존재하며, U-Net은 Skip Connection을 활용하여 이를 해결합니다. 얕은 층의 고해상도 공간 정보를 깊은 층의 의미적 정보와 결합함으로써, 세그멘테이션 작업에서 높은 성능을 유지할 수 있습니다.

# %% [markdown]
# ## 라이브러리 가져오기 및 데이터 전처리

# %%
#필요한 라이브러리 가져오기
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from torchvision import transforms,datasets

# %% [markdown]
# 데이터셋 설명: 총 30개의 세포 이미지와 각 픽셀의 레이블이 담긴 데이터셋입니다.
# train, validation, test 데이터를 각각 24, 3, 3개로 나누어 학습 및 예측을 진행합니다.
#
#
# U-Net이 아주 적은 학습 데이터셋에서도 Image segmentation을 잘 수행하고 있는지 직접 확인해보세요!

# %%
###해당 코드는 데이터셋 경로 수정 외에는 건드리지 말고 그대로 사용해주세요###

###데이터 전처리 코드###
## 라이브러리 불러오기
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

## 데이터 불러오기
dir_data = '/content/drive/MyDrive/[0825]CNN_EungyeolHAN/data'

name_label = 'train-labels.tif'
name_input = 'train-volume.tif'

img_label = Image.open(os.path.join(dir_data, name_label))
img_input = Image.open(os.path.join(dir_data, name_input))

ny, nx = img_label.size
nframe = img_label.n_frames

## train/test/val 폴더 생성
nframe_train = 24
nframe_val = 3
nframe_test = 3

dir_save_train = os.path.join(dir_data, 'train')
dir_save_val = os.path.join(dir_data, 'val')
dir_save_test = os.path.join(dir_data, 'test')

if not os.path.exists(dir_save_train):
    os.makedirs(dir_save_train)

if not os.path.exists(dir_save_val):
    os.makedirs(dir_save_val)

if not os.path.exists(dir_save_test):
    os.makedirs(dir_save_test)

## 전체 이미지 30개를 섞어줌
id_frame = np.arange(nframe)
np.random.shuffle(id_frame)

## 선택된 train 이미지를 npy 파일로 저장
offset_nframe = 0

for i in range(nframe_train):
    img_label.seek(id_frame[i + offset_nframe])
    img_input.seek(id_frame[i + offset_nframe])

    label_ = np.asarray(img_label)
    input_ = np.asarray(img_input)

    np.save(os.path.join(dir_save_train, 'label_%03d.npy' % i), label_)
    np.save(os.path.join(dir_save_train, 'input_%03d.npy' % i), input_)

## 선택된 val 이미지를 npy 파일로 저장
offset_nframe = nframe_train

for i in range(nframe_val):
    img_label.seek(id_frame[i + offset_nframe])
    img_input.seek(id_frame[i + offset_nframe])

    label_ = np.asarray(img_label)
    input_ = np.asarray(img_input)

    np.save(os.path.join(dir_save_val, 'label_%03d.npy' % i), label_)
    np.save(os.path.join(dir_save_val, 'input_%03d.npy' % i), input_)

## 선택된 test 이미지를 npy 파일로 저장
offset_nframe = nframe_train + nframe_val

for i in range(nframe_test):
    img_label.seek(id_frame[i + offset_nframe])
    img_input.seek(id_frame[i + offset_nframe])

    label_ = np.asarray(img_label)
    input_ = np.asarray(img_input)

    np.save(os.path.join(dir_save_test, 'label_%03d.npy' % i), label_)
    np.save(os.path.join(dir_save_test, 'input_%03d.npy' % i), input_)

## 이미지 시각화
plt.subplot(122)
plt.imshow(label_, cmap='gray')
plt.title('label')

plt.subplot(121)
plt.imshow(input_, cmap='gray')
plt.title('input')

plt.show()

# %% [markdown]
# ## 1. U-Net 모델 아키텍쳐 구현
#
# 제공된 reading material을 참고하여 U-Net 아키텍쳐를 구현해 보세요.
# U-Net의 구조를 하나하나 뜯어서 파악하고, input과 output featuremap size를 직접 손으로 계산해 숫자를 넣어보세요.
#
# ![image.png](data:image/png;base64,...)

# %%
import torch
from torch import nn
import torch.nn.functional as F

import pandas as pd
import numpy as np

## 네트워크 구축하기
class UNet(nn.Module):
    def __init__(self):
        super(UNet, self).__init__()

        # Convolution + BatchNormalization + Relu 정의하기
        def CBR2d(ch_in,ch_out):
            layers = []
            layers += [nn.Conv2d(in_channels=ch_in, out_channels=ch_out, padding=1, kernel_size=3)]
            layers += [nn.BatchNorm2d(num_features=ch_out)]
            layers += [nn.ReLU()]

            cbr = nn.Sequential(*layers)

            return cbr

        # 수축 경로(Contracting path)
        self.enc1_1 = CBR2d(1,64)
        self.enc1_2 = CBR2d(64,64)

        self.pool1 = nn.MaxPool2d(2, stride=2)

        self.enc2_1 = CBR2d(64,128)
        self.enc2_2 = CBR2d(128,128)

        self.pool2 = nn.MaxPool2d(2, stride=2)

        self.enc3_1 = CBR2d(128,256)
        self.enc3_2 = CBR2d(256,256)

        self.pool3 = nn.MaxPool2d(2, stride=2)

        self.enc4_1 = CBR2d(256,512)
        self.enc4_2 = CBR2d(512,512)

        self.pool4 = nn.MaxPool2d(2, stride=2)

        self.enc5_1 = CBR2d(512,1024)

        # 확장 경로(Expansive path)
        self.dec5_1 = CBR2d(1024,512)

        self.unpool4 = nn.ConvTranspose2d(in_channels=512, out_channels=512, kernel_size=2, stride=2)

        self.dec4_2 = CBR2d(1024,512)
        self.dec4_1 = CBR2d(512,256)

        self.unpool3 = nn.ConvTranspose2d(in_channels=256, out_channels=256, kernel_size=2, stride=2)

        self.dec3_2 = CBR2d(512,256)
        self.dec3_1 = CBR2d(256,128)

        self.unpool2 = nn.ConvTranspose2d(in_channels=128, out_channels=128, kernel_size=2, stride=2)

        self.dec2_2 = CBR2d(256,128)
        self.dec2_1 = CBR2d(128,64)

        self.unpool1 = nn.ConvTranspose2d(in_channels=64, out_channels=64, kernel_size=2, stride=2)

        self.dec1_2 = CBR2d(128,64)
        self.dec1_1 = CBR2d(64,64)

        self.fc = nn.Conv2d(in_channels=64, out_channels=1, kernel_size=1)

    # forward 함수 정의하기
    def forward(self, x):
        enc1_1 = self.enc1_1(x)
        enc1_2 = self.enc1_2(enc1_1)
        pool1 = self.pool1(enc1_2)

        enc2_1 = self.enc2_1(pool1)
        enc2_2 = self.enc2_2(enc2_1)
        pool2 = self.pool2(enc2_2)

        enc3_1 = self.enc3_1(pool2)
        enc3_2 = self.enc3_2(enc3_1)
        pool3 = self.pool3(enc3_2)

        enc4_1 = self.enc4_1(pool3)
        enc4_2 = self.enc4_2(enc4_1)
        pool4 = self.pool4(enc4_2)

        enc5_1 = self.enc5_1(pool4)

        dec5_1 = self.dec5_1(enc5_1)

        unpool4 = self.unpool4(dec5_1)
        cat4 = torch.cat((unpool4, enc4_2), dim=1)
        dec4_2 = self.dec4_2(cat4)
        dec4_1 = self.dec4_1(dec4_2)

        unpool3 = self.unpool3(dec4_1)
        cat3 = torch.cat((unpool3, enc3_2), dim=1)
        dec3_2 = self.dec3_2(cat3)
        dec3_1 = self.dec3_1(dec3_2)

        unpool2 = self.unpool2(dec3_1)
        cat2 = torch.cat((unpool2, enc2_2), dim=1)
        dec2_2 = self.dec2_2(cat2)
        dec2_1 = self.dec2_1(dec2_2)

        unpool1 = self.unpool1(dec2_1)
        cat1 = torch.cat((unpool1, enc1_2), dim=1)
        dec1_2 = self.dec1_2(cat1)
        dec1_1 = self.dec1_1(dec1_2)

        x = self.fc(dec1_1)

        return x

# %% [markdown]
# ## 2. Dataset & Transform
# 데이터가 흘러갈 네트워크를 앞서 선언해 주었습니다. 이제 데이터를 잘 처리해서 네트워크에 흘려보내주면 됩니다. 파이토치는 데이터를 불러오고 변환하는 과정을 Dataset class와 Transform class로 구현합니다. 해당 Dataset class 부분은 빈칸을 뚫어놓지 않았습니다. 코드를 찬찬히 살펴봐주세요.

# %%
######  코드 수정 금지  ######
# 데이터 로더 구현하기
class Dataset(torch.utils.data.Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.transform = transform

        lst_data = os.listdir(self.data_dir)

        lst_label = [f for f in lst_data if f.startswith('label')]
        lst_input = [f for f in lst_data if f.startswith('input')]

        lst_label.sort()
        lst_input.sort()

        self.lst_label = lst_label
        self.lst_input = lst_input

    def __len__(self):
        return len(self.lst_label)

    def __getitem__(self, index):
        label = np.load(os.path.join(self.data_dir, self.lst_label[index]))
        input = np.load(os.path.join(self.data_dir, self.lst_input[index]))

        # 정규화
        label = label/255.0
        input = input/255.0

        # 이미지와 레이블의 차원 = 2일 경우(채널이 없을 경우, 흑백 이미지), 새로운 채널(축) 생성
        if label.ndim == 2:
            label = label[:, :, np.newaxis]
        if input.ndim == 2:
            input = input[:, :, np.newaxis]

        data = {'input': input, 'label': label}

        # transform이 정의되어 있다면 transform을 거친 데이터를 불러옴
        if self.transform:
            data = self.transform(data)

        return data

# %% [markdown]
# 다음은 Transform인데, 이 부분은 여러분의 직관에 따라 원하는 전처리를 진행해주면 됩니다. 일반적으로 데이터가 numpy 형태라면 tensor로 바꿔주고, 이미지의 경우 Flip(방향 뒤집기)을 통해 data augumentation 효과를 주기도 합니다. 해당 코드는 데이터가 np 형태이므로 tensor로 바꿔주었고, 이미지이므로 언급한 두 변환에 더해 정규화도 취하고 있습니다.
# \
# \
# 외에 더하고 싶은 것을 추가해도 좋습니다. 자유롭게 수정해보세요 !

# %% [markdown]
# ### 문제 3.
#
# 모델의 generalization을 높여주기 위해 Augmentation을 사용할 수 있다고 했습니다.
#
# PyTorch 구현상으로는 train, validation, test 모든 단계에 Augmention를 구현할 수 있습니다만, 실제로는 train 단계에서만 Augmention를 수행하게 됩니다. 그 이유에 대해서 설명해주세요.

# %% [markdown]
# [풀이]

# %%
class ToTensor(object):
    def __call__(self, data):
        label, input = data['label'], data['input']

        # numpy와 tensor의 배열 차원 순서가 다르다.
        # numpy : (행, 열, 채널)
        # tensor : (채널, 행, 열)
        # 따라서 위 순서에 맞춰 transpose

        label = np.transpose(label, axes=(2,0,1)).astype(np.float32)
        input = np.transpose(input, axes=(2,0,1)).astype(np.float32)

        data = {'label': torch.from_numpy(label), 'input': torch.from_numpy(input)}

        return data

######  수정 금지  ######
class Normalization(object):
    def __init__(self, mean=0.5, std=0.5):
        self.mean = mean
        self.std = std

    def __call__(self, data):
        label, input = data['label'], data['input']

        input = (input - self.mean) / self.std

        data = {'label': label, 'input': input}

        return data


######  TODO를 채우고 또 다른 기능을 자유롭게 추가해보세용  ######
class RandomFlip(object):
    def __call__(self, data):
        label, input = data['label'], data['input']

        if np.random.rand() > 0.5:
            label = np.flip(label, axis=0)
            input = np.flip(input, axis=0)

        if np.random.rand() > 0.5:
            label = np.flip(label, axis=0)
            input = np.flip(input, axis=0)

        data = {'label': label, 'input': input}

        return data


#Random Rotation
class RandomRotate(object):
    def __call__(self, data):
        label, input = data['label'], data['input']

        if np.random.rand() > 0.5:
            degree = np.random.randint(4)
            label = np.rot90(label, degree, axes=(0,1))
            input = np.rot90(input, degree, axes=(0,1))

        data = {'label': label, 'input': input}

        return data


class RandomShift(object):
    def __init__(self, shift_range=20):
        self.shift_range = shift_range

    def __call__(self, data):
        label, input = data['label'], data['input']
        shift_x = np.random.randint(-self.shift_range, self.shift_range)
        shift_y = np.random.randint(-self.shift_range, self.shift_range)

        label = np.roll(label, shift_x, axis=1)
        label = np.roll(label, shift_y, axis=0)
        input = np.roll(input, shift_x, axis=1)
        input = np.roll(input, shift_y, axis=0)

        data = {'label': label, 'input': input}
        return data

# %%
######  코드 수정 금지  ######
## 네트워크 저장하기
def save(ckpt_dir, net, optim, epoch):
    if not os.path.exists(ckpt_dir):
        os.makedirs(ckpt_dir)

    torch.save({'net': net.state_dict(), 'optim': optim.state_dict()},
               "%s/model_epoch%d.pth" % (ckpt_dir, epoch))

## 네트워크 불러오기
def load(ckpt_dir, net, optim):
    if not os.path.exists(ckpt_dir):
        epoch = 0
        return net, optim, epoch

    ckpt_lst = os.listdir(ckpt_dir)
    ckpt_lst.sort(key=lambda f: int(''.join(filter(str.isdigit, f))))

    dict_model = torch.load('%s/%s' % (ckpt_dir, ckpt_lst[-1]))

    net.load_state_dict(dict_model['net'])
    optim.load_state_dict(dict_model['optim'])
    epoch = int(ckpt_lst[-1].split('epoch')[1].split('.pth')[0])

    return net, optim, epoch

# %% [markdown]
# ## 문제 4.
#
# U-Net 모델의 논문에서는 biomedical image segmentation에 최적화된 손실함수를 다음과 같이 따로 정의하고 있습니다.
#
# ![image.png](data:image/png;base64,...)
#
# 여기서 1) 가중치 w(x)의 의미는 무엇인지, 2) 가중치가 커지는 조건은 무엇인지, 3) 이러한 새로운 손실함수 정의의 목적(해당 task만의 특징에 기반하여)은 무엇인지 말로 풀어서 설명해주세요.

# %% [markdown]
# [풀이]
# 1. 가중치 w(x)는 U-Net 모델에서 사용되는 손실 함수에서 특정 픽셀 위치 x에 대해 손실 값에 대한 중요도를 결정하는 역할을 합니다.
# 2. 가중치 w(x)는 픽셀 x가 객체 경계 근처에 있을 때 커집니다.
# 3. 이 손실 함수의 정의는 biomedical image segmentation에서 경계를 더 명확하게 분할하기 위한 것입니다. 전통적인 손실 함수는 경계 영역의 픽셀을 충분히 잘 학습하지 못하는 경우가 많습니다. 특히, 생물의학 영상에서 세포나 장기의 경계는 중요한 의미를 가지므로, 이 손실 함수는 경계 영역을 강조하여 경계가 잘 보존되도록 설계되었습니다.

# %% [markdown]
# ## 3. 손실함수 정의
#
# U-Net 논문을 통해 우리는 이들이 biomedical image segmentation을 위해 세포의 border pixel에 가중치를 두도록 하는 독특한 손실함수를 새로 정의하고 있음을 알 수 있습니다.
#
# 아래의 코드를 통해 해당 손실함수를 구현해보고, 기존의 nn.BCEWithLogitsLoss()와 비교하여 성능에 차이가 있는지, 있다면 어느 손실함수를 택하는 것이 효과적인지 고려해봅시다.

# %% [markdown]
# ** from scipy.ndimage import distance_transform_edt \
#
# ->  SciPy 라이브러리의 ndimage 모듈에 포함된 함수로, 이진 이미지에서 각 픽셀까지의 최단 거리(유클리드 거리)를 계산한다 !
#
# 주요 개념\
# 이진 이미지: 픽셀 값이 0 또는 1인 이미지. 1은 객체가 있는 영역, 0은 배경을 의미한다.\
# 거리 변환: 각 픽셀에서 가장 가까운 0이 아닌 픽셀까지의 거리 값을 계산. 이 거리 값은 유클리드 거리를 사용하여 측정된다.

# %%
from torch.utils.tensorboard import SummaryWriter
from scipy.ndimage import distance_transform_edt

# 사용자 정의 WeightedBCEWithLogitsLoss 구현
class WeightedBCEWithLogitsLoss(nn.Module):
    def __init__(self, border_weight=5):
        super(WeightedBCEWithLogitsLoss, self).__init__()
        self.bce_loss = nn.BCEWithLogitsLoss(reduction='none')  # 가중치를 직접 적용하기 위해 'none' 사용
        self.border_weight = border_weight

    def forward(self, inputs, targets):
        # BCE 손실 계산
        bce = self.bce_loss(inputs, targets)

        # 경계 가중치 맵 생성
        weight_map = create_border_weight_map(targets, self.border_weight).to(inputs.device)
        bce *= weight_map

        # 평균 손실 계산
        return bce.mean()

def create_border_weight_map(targets, border_weight=5):
    """
    경계 픽셀에 가중치를 부여하기 위한 가중치 맵 생성.
    :param targets: 실제 라벨 (0과 1 사이의 값)
    :param border_weight: 경계 픽셀에 적용할 가중치
    :return: 가중치 맵
    """
    weight_map = torch.ones_like(targets)
    targets_np = targets.cpu().numpy()

    for i in range(targets_np.shape[0]):  # 배치 내 각 샘플에 대해
        distance_to_foreground = distance_transform_edt(targets_np[i] == 0)
        distance_to_background = distance_transform_edt(targets_np[i] == 1)
        border_mask = (distance_to_foreground + distance_to_background) <= 2
        weight_map[i][border_mask] = border_weight

    return weight_map

# %% [markdown]
# ## 4. Training

# %%
######  코드 수정 금지  ######
# 정확도 계산 함수 정의

def compute_accuracy(predictions, labels, threshold=0.5):
    """ Calculate pixel-wise accuracy. """
    with torch.no_grad():
        # threshold를 기준으로 예측 값을 바이너리로 변환
        pred_binary = (predictions > threshold).float()

        # 정확한 예측 픽셀의 비율을 계산
        correct_pixels = torch.sum(pred_binary == labels).item()
        total_pixels = torch.numel(labels)

        return correct_pixels / total_pixels

# %%
# 훈련 파라미터 설정하기
lr = 1e-3
batch_size = 4
num_epoch = 100

#파일 생성 코드입니다. 해당 파일을 생성하고자 하는 경로를 적절히 설정해주세요.#
base_dir = '/content/drive/MyDrive/[0825]CNN_EungyeolHAN'
data_dir = dir_data
ckpt_dir = os.path.join(base_dir, "checkpoint")
log_dir = os.path.join(base_dir, "log")


# 훈련을 위한 Transform과 DataLoader
transform = transforms.Compose([Normalization(mean=0.5, std=0.5), RandomFlip(), RandomRotate(), RandomShift(), ToTensor()])

dataset_train = Dataset(data_dir=os.path.join(data_dir, 'train'), transform=transform)
loader_train = DataLoader(dataset_train, batch_size=batch_size, shuffle=True, num_workers=8)

dataset_val = Dataset(data_dir=os.path.join(data_dir, 'val'), transform=transform)
loader_val = DataLoader(dataset_val, batch_size=batch_size, shuffle=False, num_workers=8)

# 네트워크 생성하기
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
net = UNet().to(device)

# 손실함수 정의하기
fn_loss = WeightedBCEWithLogitsLoss(border_weight=5).to(device)
fn_loss = nn.BCEWithLogitsLoss().to(device)

# Optimizer 설정하기
optim = torch.optim.Adam(net.parameters(), lr=lr)

# 그밖에 부수적인 variables 설정하기
num_data_train = len(dataset_train)
num_data_val = len(dataset_val)

num_batch_train = np.ceil(num_data_train / batch_size)
num_batch_val = np.ceil(num_data_val / batch_size)

# 그 밖에 부수적인 functions 설정하기
fn_tonumpy = lambda x: x.to('cpu').detach().numpy().transpose(0, 2, 3, 1)
fn_denorm = lambda x, mean, std: (x * std) + mean
fn_class = lambda x: 1.0 * (x > 0.5)

# Tensorboard 를 사용하기 위한 SummaryWriter 설정
writer_train = SummaryWriter(log_dir=os.path.join(log_dir, 'train'))
writer_val = SummaryWriter(log_dir=os.path.join(log_dir, 'val'))

# %%
# 네트워크 학습시키기
st_epoch = 0
# 학습한 모델이 있을 경우 모델 로드하기
net, optim, st_epoch = load(ckpt_dir=ckpt_dir, net=net, optim=optim)

for epoch in range(st_epoch + 1, num_epoch + 1):
    net.train()
    loss_arr = []
    accuracy_arr = []

    for batch, data in enumerate(loader_train, 1):
        # forward pass
        label = data['label'].to(device)
        input = data['input'].to(device)

        output = net(input)

        # backward pass
        optim.zero_grad()

        loss = fn_loss(output, label)
        loss.backward()
        optim.step()

        # 손실함수 계산
        loss_arr.append(loss.item())

        # 정확도 계산
        acc = compute_accuracy(output, label)
        accuracy_arr.append(acc)

        print("TRAIN: EPOCH %04d / %04d | BATCH %04d / %04d | LOSS %.4f | ACCURACY %.4f" %
              (epoch, num_epoch, batch, num_batch_train, np.mean(loss_arr), np.mean(accuracy_arr)))

        # Tensorboard 저장하기
        label = fn_tonumpy(label)
        input = fn_tonumpy(fn_denorm(input, mean=0.5, std=0.5))
        output = fn_tonumpy(fn_class(output))

        writer_train.add_image('label', label, num_batch_train * (epoch - 1) + batch, dataformats='NHWC')
        writer_train.add_image('input', input, num_batch_train * (epoch - 1) + batch, dataformats='NHWC')
        writer_train.add_image('output', output, num_batch_train * (epoch - 1) + batch, dataformats='NHWC')

    writer_train.add_scalar('loss', np.mean(loss_arr), epoch)
    writer_train.add_scalar('accuracy', np.mean(accuracy_arr), epoch)

    with torch.no_grad():
        net.eval()
        loss_arr = []
        accuracy_arr = []

        for batch, data in enumerate(loader_val, 1):
            # forward pass
            label = data['label'].to(device)
            input = data['input'].to(device)

            output = net(input)

            # 손실함수 계산하기
            loss = fn_loss(output, label)
            loss_arr.append(loss.item())

            # 정확도 계산
            acc = compute_accuracy(output, label)
            accuracy_arr.append(acc)

            print("VALID: EPOCH %04d / %04d | BATCH %04d / %04d | LOSS %.4f | ACCURACY %.4f" %
                  (epoch, num_epoch, batch, num_batch_val, np.mean(loss_arr), np.mean(accuracy_arr)))

            # Tensorboard 저장하기
            label = fn_tonumpy(label)
            input = fn_tonumpy(fn_denorm(input, mean=0.5, std=0.5))
            output = fn_tonumpy(fn_class(output))

            writer_val.add_image('label', label, num_batch_val * (epoch - 1) + batch, dataformats='NHWC')
            writer_val.add_image('input', input, num_batch_val * (epoch - 1) + batch, dataformats='NHWC')
            writer_val.add_image('output', output, num_batch_val * (epoch - 1) + batch, dataformats='NHWC')

        writer_val.add_scalar('loss', np.mean(loss_arr), epoch)
        writer_val.add_scalar('accuracy', np.mean(accuracy_arr), epoch)

    # epoch 50마다 모델 저장하기
    if epoch % 50 == 0:
        save(ckpt_dir=ckpt_dir, net=net, optim=optim, epoch=epoch)

writer_train.close()
writer_val.close()
# Out:
# TRAIN: EPOCH 0001 / 0100 | BATCH 0001 / 0006 | LOSS 0.6775 | ACCURACY 0.2805
# TRAIN: EPOCH 0001 / 0100 | BATCH 0002 / 0006 | LOSS 0.6153 | ACCURACY 0.4463
# TRAIN: EPOCH 0001 / 0100 | BATCH 0003 / 0006 | LOSS 0.5775 | ACCURACY 0.5416
# TRAIN: EPOCH 0001 / 0100 | BATCH 0004 / 0006 | LOSS 0.5605 | ACCURACY 0.5974
# TRAIN: EPOCH 0001 / 0100 | BATCH 0005 / 0006 | LOSS 0.5432 | ACCURACY 0.6348
# TRAIN: EPOCH 0001 / 0100 | BATCH 0006 / 0006 | LOSS 0.5237 | ACCURACY 0.6596
# VALID: EPOCH 0001 / 0100 | BATCH 0001 / 0001 | LOSS 0.6114 | ACCURACY 0.1960
# TRAIN: EPOCH 0002 / 0100 | BATCH 0001 / 0006 | LOSS 0.4340 | ACCURACY 0.7936
# TRAIN: EPOCH 0002 / 0100 | BATCH 0002 / 0006 | LOSS 0.4168 | ACCURACY 0.7999
# TRAIN: EPOCH 0002 / 0100 | BATCH 0003 / 0006 | LOSS 0.4110 | ACCURACY 0.8094
# TRAIN: EPOCH 0002 / 0100 | BATCH 0004 / 0006 | LOSS 0.4023 | ACCURACY 0.8178
# TRAIN: EPOCH 0002 / 0100 | BATCH 0005 / 0006 | LOSS 0.3959 | ACCURACY 0.8234
# TRAIN: EPOCH 0002 / 0100 | BATCH 0006 / 0006 | LOSS 0.3978 | ACCURACY 0.8204
# VALID: EPOCH 0002 / 0100 | BATCH 0001 / 0001 | LOSS 0.4936 | ACCURACY 0.8255
# TRAIN: EPOCH 0003 / 0100 | BATCH 0001 / 0006 | LOSS 0.3551 | ACCURACY 0.8375
# TRAIN: EPOCH 0003 / 0100 | BATCH 0002 / 0006 | LOSS 0.3596 | ACCURACY 0.8239
# TRAIN: EPOCH 0003 / 0100 | BATCH 0003 / 0006 | LOSS 0.3574 | ACCURACY 0.8221
# TRAIN: EPOCH 0003 / 0100 | BATCH 0004 / 0006 | LOSS 0.3542 | ACCURACY 0.8259
# TRAIN: EPOCH 0003 / 0100 | BATCH 0005 / 0006 | LOSS 0.3523 | ACCURACY 0.8294
# TRAIN: EPOCH 0003 / 0100 | BATCH 0006 / 0006 | LOSS 0.3465 | ACCURACY 0.8343
# VALID: EPOCH 0003 / 0100 | BATCH 0001 / 0001 | LOSS 0.4007 | ACCURACY 0.8504
# TRAIN: EPOCH 0004 / 0100 | BATCH 0001 / 0006 | LOSS 0.3447 | ACCURACY 0.8420
# TRAIN: EPOCH 0004 / 0100 | BATCH 0002 / 0006 | LOSS 0.3359 | ACCURACY 0.8551
# TRAIN: EPOCH 0004 / 0100 | BATCH 0003 / 0006 | LOSS 0.3266 | ACCURACY 0.8632
# TRAIN: EPOCH 0004 / 0100 | BATCH 0004 / 0006 | LOSS 0.3236 | ACCURACY 0.8635
# TRAIN: EPOCH 0004 / 0100 | BATCH 0005 / 0006 | LOSS 0.3196 | ACCURACY 0.8638
# TRAIN: EPOCH 0004 / 0100 | BATCH 0006 / 0006 | LOSS 0.3158 | ACCURACY 0.8653
# VALID: EPOCH 0004 / 0100 | BATCH 0001 / 0001 | LOSS 0.3570 | ACCURACY 0.8616
# TRAIN: EPOCH 0005 / 0100 | BATCH 0001 / 0006 | LOSS 0.2935 | ACCURACY 0.8746
# TRAIN: EPOCH 0005 / 0100 | BATCH 0002 / 0006 | LOSS 0.2991 | ACCURACY 0.8702
# TRAIN: EPOCH 0005 / 0100 | BATCH 0003 / 0006 | LOSS 0.2991 | ACCURACY 0.8690
# TRAIN: EPOCH 0005 / 0100 | BATCH 0004 / 0006 | LOSS 0.2964 | ACCURACY 0.8713
# TRAIN: EPOCH 0005 / 0100 | BATCH 0005 / 0006 | LOSS 0.2941 | ACCURACY 0.8748
# TRAIN: EPOCH 0005 / 0100 | BATCH 0006 / 0006 | LOSS 0.2930 | ACCURACY 0.8773
# VALID: EPOCH 0005 / 0100 | BATCH 0001 / 0001 | LOSS 0.2656 | ACCURACY 0.8997
# TRAIN: EPOCH 0006 / 0100 | BATCH 0001 / 0006 | LOSS 0.2777 | ACCURACY 0.8914
# TRAIN: EPOCH 0006 / 0100 | BATCH 0002 / 0006 | LOSS 0.2823 | ACCURACY 0.8882
# TRAIN: EPOCH 0006 / 0100 | BATCH 0003 / 0006 | LOSS 0.2797 | ACCURACY 0.8877
# TRAIN: EPOCH 0006 / 0100 | BATCH 0004 / 0006 | LOSS 0.2769 | ACCURACY 0.8876
# TRAIN: EPOCH 0006 / 0100 | BATCH 0005 / 0006 | LOSS 0.2781 | ACCURACY 0.8868
# TRAIN: EPOCH 0006 / 0100 | BATCH 0006 / 0006 | LOSS 0.2754 | ACCURACY 0.8876
# VALID: EPOCH 0006 / 0100 | BATCH 0001 / 0001 | LOSS 0.2415 | ACCURACY 0.9062
# TRAIN: EPOCH 0007 / 0100 | BATCH 0001 / 0006 | LOSS 0.2783 | ACCURACY 0.8879
# TRAIN: EPOCH 0007 / 0100 | BATCH 0002 / 0006 | LOSS 0.2701 | ACCURACY 0.8914
# TRAIN: EPOCH 0007 / 0100 | BATCH 0003 / 0006 | LOSS 0.2649 | ACCURACY 0.8937
# TRAIN: EPOCH 0007 / 0100 | BATCH 0004 / 0006 | LOSS 0.2611 | ACCURACY 0.8950
# TRAIN: EPOCH 0007 / 0100 | BATCH 0005 / 0006 | LOSS 0.2642 | ACCURACY 0.8923
# TRAIN: EPOCH 0007 / 0100 | BATCH 0006 / 0006 | LOSS 0.2643 | ACCURACY 0.8924
# VALID: EPOCH 0007 / 0100 | BATCH 0001 / 0001 | LOSS 0.2509 | ACCURACY 0.8995
# TRAIN: EPOCH 0008 / 0100 | BATCH 0001 / 0006 | LOSS 0.2597 | ACCURACY 0.8939
# TRAIN: EPOCH 0008 / 0100 | BATCH 0002 / 0006 | LOSS 0.2565 | ACCURACY 0.8960
# TRAIN: EPOCH 0008 / 0100 | BATCH 0003 / 0006 | LOSS 0.2577 | ACCURACY 0.8925
# TRAIN: EPOCH 0008 / 0100 | BATCH 0004 / 0006 | LOSS 0.2568 | ACCURACY 0.8938
# TRAIN: EPOCH 0008 / 0100 | BATCH 0005 / 0006 | LOSS 0.2550 | ACCURACY 0.8948
# TRAIN: EPOCH 0008 / 0100 | BATCH 0006 / 0006 | LOSS 0.2583 | ACCURACY 0.8927
# VALID: EPOCH 0008 / 0100 | BATCH 0001 / 0001 | LOSS 0.2452 | ACCURACY 0.8910
# TRAIN: EPOCH 0009 / 0100 | BATCH 0001 / 0006 | LOSS 0.2431 | ACCURACY 0.9038
# TRAIN: EPOCH 0009 / 0100 | BATCH 0002 / 0006 | LOSS 0.2504 | ACCURACY 0.8968
# TRAIN: EPOCH 0009 / 0100 | BATCH 0003 / 0006 | LOSS 0.2527 | ACCURACY 0.8956
# TRAIN: EPOCH 0009 / 0100 | BATCH 0004 / 0006 | LOSS 0.2506 | ACCURACY 0.8961
# TRAIN: EPOCH 0009 / 0100 | BATCH 0005 / 0006 | LOSS 0.2476 | ACCURACY 0.8971
# TRAIN: EPOCH 0009 / 0100 | BATCH 0006 / 0006 | LOSS 0.2484 | ACCURACY 0.8946
# VALID: EPOCH 0009 / 0100 | BATCH 0001 / 0001 | LOSS 0.2191 | ACCURACY 0.9114
# TRAIN: EPOCH 0010 / 0100 | BATCH 0001 / 0006 | LOSS 0.2226 | ACCURACY 0.9054
# TRAIN: EPOCH 0010 / 0100 | BATCH 0002 / 0006 | LOSS 0.2336 | ACCURACY 0.9035
# TRAIN: EPOCH 0010 / 0100 | BATCH 0003 / 0006 | LOSS 0.2326 | ACCURACY 0.9056
# TRAIN: EPOCH 0010 / 0100 | BATCH 0004 / 0006 | LOSS 0.2356 | ACCURACY 0.9035
# TRAIN: EPOCH 0010 / 0100 | BATCH 0005 / 0006 | LOSS 0.2366 | ACCURACY 0.9028
# TRAIN: EPOCH 0010 / 0100 | BATCH 0006 / 0006 | LOSS 0.2405 | ACCURACY 0.8997
# VALID: EPOCH 0010 / 0100 | BATCH 0001 / 0001 | LOSS 0.2238 | ACCURACY 0.9037
# TRAIN: EPOCH 0011 / 0100 | BATCH 0001 / 0006 | LOSS 0.2373 | ACCURACY 0.8980
# TRAIN: EPOCH 0011 / 0100 | BATCH 0002 / 0006 | LOSS 0.2366 | ACCURACY 0.8985
# TRAIN: EPOCH 0011 / 0100 | BATCH 0003 / 0006 | LOSS 0.2349 | ACCURACY 0.8987
# TRAIN: EPOCH 0011 / 0100 | BATCH 0004 / 0006 | LOSS 0.2361 | ACCURACY 0.8973
# TRAIN: EPOCH 0011 / 0100 | BATCH 0005 / 0006 | LOSS 0.2343 | ACCURACY 0.8984
# TRAIN: EPOCH 0011 / 0100 | BATCH 0006 / 0006 | LOSS 0.2359 | ACCURACY 0.8981
# VALID: EPOCH 0011 / 0100 | BATCH 0001 / 0001 | LOSS 0.2161 | ACCURACY 0.9089
# TRAIN: EPOCH 0012 / 0100 | BATCH 0001 / 0006 | LOSS 0.2302 | ACCURACY 0.8972
# TRAIN: EPOCH 0012 / 0100 | BATCH 0002 / 0006 | LOSS 0.2315 | ACCURACY 0.8966
# TRAIN: EPOCH 0012 / 0100 | BATCH 0003 / 0006 | LOSS 0.2320 | ACCURACY 0.8966
# TRAIN: EPOCH 0012 / 0100 | BATCH 0004 / 0006 | LOSS 0.2330 | ACCURACY 0.8975
# TRAIN: EPOCH 0012 / 0100 | BATCH 0005 / 0006 | LOSS 0.2309 | ACCURACY 0.8999
# TRAIN: EPOCH 0012 / 0100 | BATCH 0006 / 0006 | LOSS 0.2297 | ACCURACY 0.9001
# VALID: EPOCH 0012 / 0100 | BATCH 0001 / 0001 | LOSS 0.2162 | ACCURACY 0.9132
# TRAIN: EPOCH 0013 / 0100 | BATCH 0001 / 0006 | LOSS 0.2295 | ACCURACY 0.9047
# TRAIN: EPOCH 0013 / 0100 | BATCH 0002 / 0006 | LOSS 0.2260 | ACCURACY 0.9052
# TRAIN: EPOCH 0013 / 0100 | BATCH 0003 / 0006 | LOSS 0.2263 | ACCURACY 0.9031
# TRAIN: EPOCH 0013 / 0100 | BATCH 0004 / 0006 | LOSS 0.2276 | ACCURACY 0.8999
# TRAIN: EPOCH 0013 / 0100 | BATCH 0005 / 0006 | LOSS 0.2247 | ACCURACY 0.9000
# TRAIN: EPOCH 0013 / 0100 | BATCH 0006 / 0006 | LOSS 0.2256 | ACCURACY 0.8990
# VALID: EPOCH 0013 / 0100 | BATCH 0001 / 0001 | LOSS 0.2172 | ACCURACY 0.9082
# TRAIN: EPOCH 0014 / 0100 | BATCH 0001 / 0006 | LOSS 0.2239 | ACCURACY 0.9010
# TRAIN: EPOCH 0014 / 0100 | BATCH 0002 / 0006 | LOSS 0.2210 | ACCURACY 0.9063
# TRAIN: EPOCH 0014 / 0100 | BATCH 0003 / 0006 | LOSS 0.2235 | ACCURACY 0.9074
# TRAIN: EPOCH 0014 / 0100 | BATCH 0004 / 0006 | LOSS 0.2229 | ACCURACY 0.9074
# TRAIN: EPOCH 0014 / 0100 | BATCH 0005 / 0006 | LOSS 0.2223 | ACCURACY 0.9061
# TRAIN: EPOCH 0014 / 0100 | BATCH 0006 / 0006 | LOSS 0.2240 | ACCURACY 0.9043
# VALID: EPOCH 0014 / 0100 | BATCH 0001 / 0001 | LOSS 0.2061 | ACCURACY 0.9141
# TRAIN: EPOCH 0015 / 0100 | BATCH 0001 / 0006 | LOSS 0.2270 | ACCURACY 0.8941
# TRAIN: EPOCH 0015 / 0100 | BATCH 0002 / 0006 | LOSS 0.2212 | ACCURACY 0.8994
# TRAIN: EPOCH 0015 / 0100 | BATCH 0003 / 0006 | LOSS 0.2207 | ACCURACY 0.9006
# TRAIN: EPOCH 0015 / 0100 | BATCH 0004 / 0006 | LOSS 0.2286 | ACCURACY 0.8984
# TRAIN: EPOCH 0015 / 0100 | BATCH 0005 / 0006 | LOSS 0.2275 | ACCURACY 0.8985
# TRAIN: EPOCH 0015 / 0100 | BATCH 0006 / 0006 | LOSS 0.2272 | ACCURACY 0.8989
# VALID: EPOCH 0015 / 0100 | BATCH 0001 / 0001 | LOSS 0.2134 | ACCURACY 0.9030
# TRAIN: EPOCH 0016 / 0100 | BATCH 0001 / 0006 | LOSS 0.2130 | ACCURACY 0.9031
# TRAIN: EPOCH 0016 / 0100 | BATCH 0002 / 0006 | LOSS 0.2187 | ACCURACY 0.8968
# TRAIN: EPOCH 0016 / 0100 | BATCH 0003 / 0006 | LOSS 0.2222 | ACCURACY 0.8960
# TRAIN: EPOCH 0016 / 0100 | BATCH 0004 / 0006 | LOSS 0.2238 | ACCURACY 0.8967
# TRAIN: EPOCH 0016 / 0100 | BATCH 0005 / 0006 | LOSS 0.2233 | ACCURACY 0.8968
# TRAIN: EPOCH 0016 / 0100 | BATCH 0006 / 0006 | LOSS 0.2231 | ACCURACY 0.8977
# VALID: EPOCH 0016 / 0100 | BATCH 0001 / 0001 | LOSS 0.1919 | ACCURACY 0.9175
# TRAIN: EPOCH 0017 / 0100 | BATCH 0001 / 0006 | LOSS 0.2480 | ACCURACY 0.8873
# TRAIN: EPOCH 0017 / 0100 | BATCH 0002 / 0006 | LOSS 0.2339 | ACCURACY 0.8942
# TRAIN: EPOCH 0017 / 0100 | BATCH 0003 / 0006 | LOSS 0.2276 | ACCURACY 0.8977
# TRAIN: EPOCH 0017 / 0100 | BATCH 0004 / 0006 | LOSS 0.2276 | ACCURACY 0.8989
# TRAIN: EPOCH 0017 / 0100 | BATCH 0005 / 0006 | LOSS 0.2244 | ACCURACY 0.9014
# TRAIN: EPOCH 0017 / 0100 | BATCH 0006 / 0006 | LOSS 0.2238 | ACCURACY 0.9021
# VALID: EPOCH 0017 / 0100 | BATCH 0001 / 0001 | LOSS 0.2030 | ACCURACY 0.9169
# TRAIN: EPOCH 0018 / 0100 | BATCH 0001 / 0006 | LOSS 0.2371 | ACCURACY 0.8945
# TRAIN: EPOCH 0018 / 0100 | BATCH 0002 / 0006 | LOSS 0.2279 | ACCURACY 0.8979
# TRAIN: EPOCH 0018 / 0100 | BATCH 0003 / 0006 | LOSS 0.2210 | ACCURACY 0.9015
# TRAIN: EPOCH 0018 / 0100 | BATCH 0004 / 0006 | LOSS 0.2185 | ACCURACY 0.9022
# TRAIN: EPOCH 0018 / 0100 | BATCH 0005 / 0006 | LOSS 0.2147 | ACCURACY 0.9043
# TRAIN: EPOCH 0018 / 0100 | BATCH 0006 / 0006 | LOSS 0.2153 | ACCURACY 0.9043
# VALID: EPOCH 0018 / 0100 | BATCH 0001 / 0001 | LOSS 0.2134 | ACCURACY 0.9016
# TRAIN: EPOCH 0019 / 0100 | BATCH 0001 / 0006 | LOSS 0.2232 | ACCURACY 0.9015
# TRAIN: EPOCH 0019 / 0100 | BATCH 0002 / 0006 | LOSS 0.2136 | ACCURACY 0.9064
# TRAIN: EPOCH 0019 / 0100 | BATCH 0003 / 0006 | LOSS 0.2073 | ACCURACY 0.9083
# TRAIN: EPOCH 0019 / 0100 | BATCH 0004 / 0006 | LOSS 0.2091 | ACCURACY 0.9070
# TRAIN: EPOCH 0019 / 0100 | BATCH 0005 / 0006 | LOSS 0.2068 | ACCURACY 0.9069
# TRAIN: EPOCH 0019 / 0100 | BATCH 0006 / 0006 | LOSS 0.2097 | ACCURACY 0.9057
# VALID: EPOCH 0019 / 0100 | BATCH 0001 / 0001 | LOSS 0.1996 | ACCURACY 0.9153
# TRAIN: EPOCH 0020 / 0100 | BATCH 0001 / 0006 | LOSS 0.2032 | ACCURACY 0.9110
# TRAIN: EPOCH 0020 / 0100 | BATCH 0002 / 0006 | LOSS 0.2114 | ACCURACY 0.9058
# TRAIN: EPOCH 0020 / 0100 | BATCH 0003 / 0006 | LOSS 0.2099 | ACCURACY 0.9061
# TRAIN: EPOCH 0020 / 0100 | BATCH 0004 / 0006 | LOSS 0.2116 | ACCURACY 0.9055
# TRAIN: EPOCH 0020 / 0100 | BATCH 0005 / 0006 | LOSS 0.2139 | ACCURACY 0.9048
# TRAIN: EPOCH 0020 / 0100 | BATCH 0006 / 0006 | LOSS 0.2101 | ACCURACY 0.9062
# VALID: EPOCH 0020 / 0100 | BATCH 0001 / 0001 | LOSS 0.2010 | ACCURACY 0.9014
# TRAIN: EPOCH 0021 / 0100 | BATCH 0001 / 0006 | LOSS 0.1996 | ACCURACY 0.9068
# TRAIN: EPOCH 0021 / 0100 | BATCH 0002 / 0006 | LOSS 0.2095 | ACCURACY 0.9011
# TRAIN: EPOCH 0021 / 0100 | BATCH 0003 / 0006 | LOSS 0.2104 | ACCURACY 0.9010
# TRAIN: EPOCH 0021 / 0100 | BATCH 0004 / 0006 | LOSS 0.2093 | ACCURACY 0.9042
# TRAIN: EPOCH 0021 / 0100 | BATCH 0005 / 0006 | LOSS 0.2129 | ACCURACY 0.9034
# TRAIN: EPOCH 0021 / 0100 | BATCH 0006 / 0006 | LOSS 0.2146 | ACCURACY 0.9033
# VALID: EPOCH 0021 / 0100 | BATCH 0001 / 0001 | LOSS 0.1969 | ACCURACY 0.9084
# TRAIN: EPOCH 0022 / 0100 | BATCH 0001 / 0006 | LOSS 0.2138 | ACCURACY 0.9110
# TRAIN: EPOCH 0022 / 0100 | BATCH 0002 / 0006 | LOSS 0.2080 | ACCURACY 0.9071
# TRAIN: EPOCH 0022 / 0100 | BATCH 0003 / 0006 | LOSS 0.2043 | ACCURACY 0.9078
# TRAIN: EPOCH 0022 / 0100 | BATCH 0004 / 0006 | LOSS 0.2068 | ACCURACY 0.9064
# TRAIN: EPOCH 0022 / 0100 | BATCH 0005 / 0006 | LOSS 0.2072 | ACCURACY 0.9062
# TRAIN: EPOCH 0022 / 0100 | BATCH 0006 / 0006 | LOSS 0.2084 | ACCURACY 0.9056
# VALID: EPOCH 0022 / 0100 | BATCH 0001 / 0001 | LOSS 0.1863 | ACCURACY 0.9147
# TRAIN: EPOCH 0023 / 0100 | BATCH 0001 / 0006 | LOSS 0.2074 | ACCURACY 0.8963
# TRAIN: EPOCH 0023 / 0100 | BATCH 0002 / 0006 | LOSS 0.2042 | ACCURACY 0.9023
# TRAIN: EPOCH 0023 / 0100 | BATCH 0003 / 0006 | LOSS 0.2047 | ACCURACY 0.9041
# TRAIN: EPOCH 0023 / 0100 | BATCH 0004 / 0006 | LOSS 0.2057 | ACCURACY 0.9048
# TRAIN: EPOCH 0023 / 0100 | BATCH 0005 / 0006 | LOSS 0.2092 | ACCURACY 0.9050
# TRAIN: EPOCH 0023 / 0100 | BATCH 0006 / 0006 | LOSS 0.2114 | ACCURACY 0.9041
# VALID: EPOCH 0023 / 0100 | BATCH 0001 / 0001 | LOSS 0.1989 | ACCURACY 0.9238
# TRAIN: EPOCH 0024 / 0100 | BATCH 0001 / 0006 | LOSS 0.1926 | ACCURACY 0.9142
# TRAIN: EPOCH 0024 / 0100 | BATCH 0002 / 0006 | LOSS 0.1978 | ACCURACY 0.9110
# TRAIN: EPOCH 0024 / 0100 | BATCH 0003 / 0006 | LOSS 0.2024 | ACCURACY 0.9070
# TRAIN: EPOCH 0024 / 0100 | BATCH 0004 / 0006 | LOSS 0.2034 | ACCURACY 0.9067
# TRAIN: EPOCH 0024 / 0100 | BATCH 0005 / 0006 | LOSS 0.2047 | ACCURACY 0.9059
# TRAIN: EPOCH 0024 / 0100 | BATCH 0006 / 0006 | LOSS 0.2046 | ACCURACY 0.9055
# VALID: EPOCH 0024 / 0100 | BATCH 0001 / 0001 | LOSS 0.2133 | ACCURACY 0.8894
# TRAIN: EPOCH 0025 / 0100 | BATCH 0001 / 0006 | LOSS 0.2081 | ACCURACY 0.9039
# TRAIN: EPOCH 0025 / 0100 | BATCH 0002 / 0006 | LOSS 0.2067 | ACCURACY 0.9029
# TRAIN: EPOCH 0025 / 0100 | BATCH 0003 / 0006 | LOSS 0.2060 | ACCURACY 0.9048
# TRAIN: EPOCH 0025 / 0100 | BATCH 0004 / 0006 | LOSS 0.2044 | ACCURACY 0.9057
# TRAIN: EPOCH 0025 / 0100 | BATCH 0005 / 0006 | LOSS 0.2065 | ACCURACY 0.9064
# TRAIN: EPOCH 0025 / 0100 | BATCH 0006 / 0006 | LOSS 0.2055 | ACCURACY 0.9075
# VALID: EPOCH 0025 / 0100 | BATCH 0001 / 0001 | LOSS 0.1924 | ACCURACY 0.9104
# TRAIN: EPOCH 0026 / 0100 | BATCH 0001 / 0006 | LOSS 0.1954 | ACCURACY 0.9156
# TRAIN: EPOCH 0026 / 0100 | BATCH 0002 / 0006 | LOSS 0.2048 | ACCURACY 0.9067
# TRAIN: EPOCH 0026 / 0100 | BATCH 0003 / 0006 | LOSS 0.2089 | ACCURACY 0.9029
# TRAIN: EPOCH 0026 / 0100 | BATCH 0004 / 0006 | LOSS 0.2064 | ACCURACY 0.9037
# TRAIN: EPOCH 0026 / 0100 | BATCH 0005 / 0006 | LOSS 0.2032 | ACCURACY 0.9057
# TRAIN: EPOCH 0026 / 0100 | BATCH 0006 / 0006 | LOSS 0.2030 | ACCURACY 0.9064
# VALID: EPOCH 0026 / 0100 | BATCH 0001 / 0001 | LOSS 0.1886 | ACCURACY 0.9129
# TRAIN: EPOCH 0027 / 0100 | BATCH 0001 / 0006 | LOSS 0.2085 | ACCURACY 0.9077
# TRAIN: EPOCH 0027 / 0100 | BATCH 0002 / 0006 | LOSS 0.1994 | ACCURACY 0.9112
# TRAIN: EPOCH 0027 / 0100 | BATCH 0003 / 0006 | LOSS 0.2036 | ACCURACY 0.9062
# TRAIN: EPOCH 0027 / 0100 | BATCH 0004 / 0006 | LOSS 0.1996 | ACCURACY 0.9095
# TRAIN: EPOCH 0027 / 0100 | BATCH 0005 / 0006 | LOSS 0.2023 | ACCURACY 0.9080
# TRAIN: EPOCH 0027 / 0100 | BATCH 0006 / 0006 | LOSS 0.1996 | ACCURACY 0.9083
# VALID: EPOCH 0027 / 0100 | BATCH 0001 / 0001 | LOSS 0.1811 | ACCURACY 0.9176
# TRAIN: EPOCH 0028 / 0100 | BATCH 0001 / 0006 | LOSS 0.2012 | ACCURACY 0.9081
# TRAIN: EPOCH 0028 / 0100 | BATCH 0002 / 0006 | LOSS 0.1879 | ACCURACY 0.9140
# TRAIN: EPOCH 0028 / 0100 | BATCH 0003 / 0006 | LOSS 0.1917 | ACCURACY 0.9134
# TRAIN: EPOCH 0028 / 0100 | BATCH 0004 / 0006 | LOSS 0.1975 | ACCURACY 0.9114
# TRAIN: EPOCH 0028 / 0100 | BATCH 0005 / 0006 | LOSS 0.1973 | ACCURACY 0.9108
# TRAIN: EPOCH 0028 / 0100 | BATCH 0006 / 0006 | LOSS 0.1979 | ACCURACY 0.9109
# VALID: EPOCH 0028 / 0100 | BATCH 0001 / 0001 | LOSS 0.1894 | ACCURACY 0.9178
# TRAIN: EPOCH 0029 / 0100 | BATCH 0001 / 0006 | LOSS 0.2042 | ACCURACY 0.9069
# TRAIN: EPOCH 0029 / 0100 | BATCH 0002 / 0006 | LOSS 0.2007 | ACCURACY 0.9097
# TRAIN: EPOCH 0029 / 0100 | BATCH 0003 / 0006 | LOSS 0.2017 | ACCURACY 0.9060
# TRAIN: EPOCH 0029 / 0100 | BATCH 0004 / 0006 | LOSS 0.2011 | ACCURACY 0.9050
# TRAIN: EPOCH 0029 / 0100 | BATCH 0005 / 0006 | LOSS 0.1999 | ACCURACY 0.9056
# TRAIN: EPOCH 0029 / 0100 | BATCH 0006 / 0006 | LOSS 0.1988 | ACCURACY 0.9067
# VALID: EPOCH 0029 / 0100 | BATCH 0001 / 0001 | LOSS 0.2022 | ACCURACY 0.9023
# TRAIN: EPOCH 0030 / 0100 | BATCH 0001 / 0006 | LOSS 0.1990 | ACCURACY 0.9127
# TRAIN: EPOCH 0030 / 0100 | BATCH 0002 / 0006 | LOSS 0.2012 | ACCURACY 0.9098
# TRAIN: EPOCH 0030 / 0100 | BATCH 0003 / 0006 | LOSS 0.2004 | ACCURACY 0.9099
# TRAIN: EPOCH 0030 / 0100 | BATCH 0004 / 0006 | LOSS 0.1974 | ACCURACY 0.9111
# TRAIN: EPOCH 0030 / 0100 | BATCH 0005 / 0006 | LOSS 0.1939 | ACCURACY 0.9117
# TRAIN: EPOCH 0030 / 0100 | BATCH 0006 / 0006 | LOSS 0.2004 | ACCURACY 0.9089
# VALID: EPOCH 0030 / 0100 | BATCH 0001 / 0001 | LOSS 0.1784 | ACCURACY 0.9203
# TRAIN: EPOCH 0031 / 0100 | BATCH 0001 / 0006 | LOSS 0.1916 | ACCURACY 0.9140
# TRAIN: EPOCH 0031 / 0100 | BATCH 0002 / 0006 | LOSS 0.1868 | ACCURACY 0.9165
# TRAIN: EPOCH 0031 / 0100 | BATCH 0003 / 0006 | LOSS 0.1963 | ACCURACY 0.9134
# TRAIN: EPOCH 0031 / 0100 | BATCH 0004 / 0006 | LOSS 0.1996 | ACCURACY 0.9107
# TRAIN: EPOCH 0031 / 0100 | BATCH 0005 / 0006 | LOSS 0.2013 | ACCURACY 0.9095
# TRAIN: EPOCH 0031 / 0100 | BATCH 0006 / 0006 | LOSS 0.2012 | ACCURACY 0.9082
# VALID: EPOCH 0031 / 0100 | BATCH 0001 / 0001 | LOSS 0.1809 | ACCURACY 0.9207
# TRAIN: EPOCH 0032 / 0100 | BATCH 0001 / 0006 | LOSS 0.1989 | ACCURACY 0.9062
# TRAIN: EPOCH 0032 / 0100 | BATCH 0002 / 0006 | LOSS 0.1973 | ACCURACY 0.9110
# TRAIN: EPOCH 0032 / 0100 | BATCH 0003 / 0006 | LOSS 0.2019 | ACCURACY 0.9091
# TRAIN: EPOCH 0032 / 0100 | BATCH 0004 / 0006 | LOSS 0.1981 | ACCURACY 0.9110
# TRAIN: EPOCH 0032 / 0100 | BATCH 0005 / 0006 | LOSS 0.1977 | ACCURACY 0.9104
# TRAIN: EPOCH 0032 / 0100 | BATCH 0006 / 0006 | LOSS 0.1994 | ACCURACY 0.9091
# VALID: EPOCH 0032 / 0100 | BATCH 0001 / 0001 | LOSS 0.1937 | ACCURACY 0.9113
# TRAIN: EPOCH 0033 / 0100 | BATCH 0001 / 0006 | LOSS 0.1982 | ACCURACY 0.9127
# TRAIN: EPOCH 0033 / 0100 | BATCH 0002 / 0006 | LOSS 0.1982 | ACCURACY 0.9139
# TRAIN: EPOCH 0033 / 0100 | BATCH 0003 / 0006 | LOSS 0.1990 | ACCURACY 0.9101
# TRAIN: EPOCH 0033 / 0100 | BATCH 0004 / 0006 | LOSS 0.2048 | ACCURACY 0.9062
# TRAIN: EPOCH 0033 / 0100 | BATCH 0005 / 0006 | LOSS 0.1997 | ACCURACY 0.9080
# TRAIN: EPOCH 0033 / 0100 | BATCH 0006 / 0006 | LOSS 0.2003 | ACCURACY 0.9079
# VALID: EPOCH 0033 / 0100 | BATCH 0001 / 0001 | LOSS 0.1942 | ACCURACY 0.9108
# TRAIN: EPOCH 0034 / 0100 | BATCH 0001 / 0006 | LOSS 0.2052 | ACCURACY 0.9106
# TRAIN: EPOCH 0034 / 0100 | BATCH 0002 / 0006 | LOSS 0.1976 | ACCURACY 0.9117
# TRAIN: EPOCH 0034 / 0100 | BATCH 0003 / 0006 | LOSS 0.2009 | ACCURACY 0.9103
# TRAIN: EPOCH 0034 / 0100 | BATCH 0004 / 0006 | LOSS 0.1999 | ACCURACY 0.9100
# TRAIN: EPOCH 0034 / 0100 | BATCH 0005 / 0006 | LOSS 0.2004 | ACCURACY 0.9091
# TRAIN: EPOCH 0034 / 0100 | BATCH 0006 / 0006 | LOSS 0.1979 | ACCURACY 0.9094
# VALID: EPOCH 0034 / 0100 | BATCH 0001 / 0001 | LOSS 0.1993 | ACCURACY 0.9040
# TRAIN: EPOCH 0035 / 0100 | BATCH 0001 / 0006 | LOSS 0.1953 | ACCURACY 0.9054
# TRAIN: EPOCH 0035 / 0100 | BATCH 0002 / 0006 | LOSS 0.1979 | ACCURACY 0.9048
# TRAIN: EPOCH 0035 / 0100 | BATCH 0003 / 0006 | LOSS 0.1992 | ACCURACY 0.9060
# TRAIN: EPOCH 0035 / 0100 | BATCH 0004 / 0006 | LOSS 0.1996 | ACCURACY 0.9071
# TRAIN: EPOCH 0035 / 0100 | BATCH 0005 / 0006 | LOSS 0.1998 | ACCURACY 0.9082
# TRAIN: EPOCH 0035 / 0100 | BATCH 0006 / 0006 | LOSS 0.2027 | ACCURACY 0.9078
# VALID: EPOCH 0035 / 0100 | BATCH 0001 / 0001 | LOSS 0.2052 | ACCURACY 0.9166
# TRAIN: EPOCH 0036 / 0100 | BATCH 0001 / 0006 | LOSS 0.2049 | ACCURACY 0.9011
# TRAIN: EPOCH 0036 / 0100 | BATCH 0002 / 0006 | LOSS 0.2024 | ACCURACY 0.9020
# TRAIN: EPOCH 0036 / 0100 | BATCH 0003 / 0006 | LOSS 0.2010 | ACCURACY 0.9041
# TRAIN: EPOCH 0036 / 0100 | BATCH 0004 / 0006 | LOSS 0.2028 | ACCURACY 0.9036
# TRAIN: EPOCH 0036 / 0100 | BATCH 0005 / 0006 | LOSS 0.2050 | ACCURACY 0.9034
# TRAIN: EPOCH 0036 / 0100 | BATCH 0006 / 0006 | LOSS 0.2029 | ACCURACY 0.9048
# VALID: EPOCH 0036 / 0100 | BATCH 0001 / 0001 | LOSS 0.1903 | ACCURACY 0.9119
# TRAIN: EPOCH 0037 / 0100 | BATCH 0001 / 0006 | LOSS 0.1902 | ACCURACY 0.9080
# TRAIN: EPOCH 0037 / 0100 | BATCH 0002 / 0006 | LOSS 0.1941 | ACCURACY 0.9082
# TRAIN: EPOCH 0037 / 0100 | BATCH 0003 / 0006 | LOSS 0.1981 | ACCURACY 0.9085
# TRAIN: EPOCH 0037 / 0100 | BATCH 0004 / 0006 | LOSS 0.2039 | ACCURACY 0.9061
# TRAIN: EPOCH 0037 / 0100 | BATCH 0005 / 0006 | LOSS 0.2016 | ACCURACY 0.9066
# TRAIN: EPOCH 0037 / 0100 | BATCH 0006 / 0006 | LOSS 0.1995 | ACCURACY 0.9081
# VALID: EPOCH 0037 / 0100 | BATCH 0001 / 0001 | LOSS 0.1955 | ACCURACY 0.9023
# TRAIN: EPOCH 0038 / 0100 | BATCH 0001 / 0006 | LOSS 0.1950 | ACCURACY 0.9063
# TRAIN: EPOCH 0038 / 0100 | BATCH 0002 / 0006 | LOSS 0.1975 | ACCURACY 0.9072
# TRAIN: EPOCH 0038 / 0100 | BATCH 0003 / 0006 | LOSS 0.1911 | ACCURACY 0.9095
# TRAIN: EPOCH 0038 / 0100 | BATCH 0004 / 0006 | LOSS 0.1936 | ACCURACY 0.9091
# TRAIN: EPOCH 0038 / 0100 | BATCH 0005 / 0006 | LOSS 0.1924 | ACCURACY 0.9106
# TRAIN: EPOCH 0038 / 0100 | BATCH 0006 / 0006 | LOSS 0.1949 | ACCURACY 0.9098
# VALID: EPOCH 0038 / 0100 | BATCH 0001 / 0001 | LOSS 0.2084 | ACCURACY 0.8952
# TRAIN: EPOCH 0039 / 0100 | BATCH 0001 / 0006 | LOSS 0.1842 | ACCURACY 0.9181
# TRAIN: EPOCH 0039 / 0100 | BATCH 0002 / 0006 | LOSS 0.1933 | ACCURACY 0.9137
# TRAIN: EPOCH 0039 / 0100 | BATCH 0003 / 0006 | LOSS 0.1974 | ACCURACY 0.9117
# TRAIN: EPOCH 0039 / 0100 | BATCH 0004 / 0006 | LOSS 0.1949 | ACCURACY 0.9124
# TRAIN: EPOCH 0039 / 0100 | BATCH 0005 / 0006 | LOSS 0.1945 | ACCURACY 0.9116
# TRAIN: EPOCH 0039 / 0100 | BATCH 0006 / 0006 | LOSS 0.1963 | ACCURACY 0.9108
# VALID: EPOCH 0039 / 0100 | BATCH 0001 / 0001 | LOSS 0.1844 | ACCURACY 0.9183
# TRAIN: EPOCH 0040 / 0100 | BATCH 0001 / 0006 | LOSS 0.1924 | ACCURACY 0.9160
# TRAIN: EPOCH 0040 / 0100 | BATCH 0002 / 0006 | LOSS 0.1896 | ACCURACY 0.9158
# TRAIN: EPOCH 0040 / 0100 | BATCH 0003 / 0006 | LOSS 0.1878 | ACCURACY 0.9168
# TRAIN: EPOCH 0040 / 0100 | BATCH 0004 / 0006 | LOSS 0.1870 | ACCURACY 0.9160
# TRAIN: EPOCH 0040 / 0100 | BATCH 0005 / 0006 | LOSS 0.1867 | ACCURACY 0.9159
# TRAIN: EPOCH 0040 / 0100 | BATCH 0006 / 0006 | LOSS 0.1943 | ACCURACY 0.9121
# VALID: EPOCH 0040 / 0100 | BATCH 0001 / 0001 | LOSS 0.1806 | ACCURACY 0.9202
# TRAIN: EPOCH 0041 / 0100 | BATCH 0001 / 0006 | LOSS 0.1964 | ACCURACY 0.9103
# TRAIN: EPOCH 0041 / 0100 | BATCH 0002 / 0006 | LOSS 0.1921 | ACCURACY 0.9105
# TRAIN: EPOCH 0041 / 0100 | BATCH 0003 / 0006 | LOSS 0.1910 | ACCURACY 0.9107
# TRAIN: EPOCH 0041 / 0100 | BATCH 0004 / 0006 | LOSS 0.1949 | ACCURACY 0.9094
# TRAIN: EPOCH 0041 / 0100 | BATCH 0005 / 0006 | LOSS 0.1940 | ACCURACY 0.9105
# TRAIN: EPOCH 0041 / 0100 | BATCH 0006 / 0006 | LOSS 0.1940 | ACCURACY 0.9109
# VALID: EPOCH 0041 / 0100 | BATCH 0001 / 0001 | LOSS 0.1895 | ACCURACY 0.9067
# TRAIN: EPOCH 0042 / 0100 | BATCH 0001 / 0006 | LOSS 0.1819 | ACCURACY 0.9180
# TRAIN: EPOCH 0042 / 0100 | BATCH 0002 / 0006 | LOSS 0.1915 | ACCURACY 0.9139
# TRAIN: EPOCH 0042 / 0100 | BATCH 0003 / 0006 | LOSS 0.1882 | ACCURACY 0.9165
# TRAIN: EPOCH 0042 / 0100 | BATCH 0004 / 0006 | LOSS 0.1900 | ACCURACY 0.9153
# TRAIN: EPOCH 0042 / 0100 | BATCH 0005 / 0006 | LOSS 0.1910 | ACCURACY 0.9142
# TRAIN: EPOCH 0042 / 0100 | BATCH 0006 / 0006 | LOSS 0.1935 | ACCURACY 0.9132
# VALID: EPOCH 0042 / 0100 | BATCH 0001 / 0001 | LOSS 0.1778 | ACCURACY 0.9147
# TRAIN: EPOCH 0043 / 0100 | BATCH 0001 / 0006 | LOSS 0.1887 | ACCURACY 0.9092
# TRAIN: EPOCH 0043 / 0100 | BATCH 0002 / 0006 | LOSS 0.1930 | ACCURACY 0.9073
# TRAIN: EPOCH 0043 / 0100 | BATCH 0003 / 0006 | LOSS 0.1948 | ACCURACY 0.9080
# TRAIN: EPOCH 0043 / 0100 | BATCH 0004 / 0006 | LOSS 0.1932 | ACCURACY 0.9082
# TRAIN: EPOCH 0043 / 0100 | BATCH 0005 / 0006 | LOSS 0.1910 | ACCURACY 0.9102
# TRAIN: EPOCH 0043 / 0100 | BATCH 0006 / 0006 | LOSS 0.1901 | ACCURACY 0.9117
# VALID: EPOCH 0043 / 0100 | BATCH 0001 / 0001 | LOSS 0.1758 | ACCURACY 0.9232
# TRAIN: EPOCH 0044 / 0100 | BATCH 0001 / 0006 | LOSS 0.1855 | ACCURACY 0.9131
# TRAIN: EPOCH 0044 / 0100 | BATCH 0002 / 0006 | LOSS 0.1876 | ACCURACY 0.9138
# TRAIN: EPOCH 0044 / 0100 | BATCH 0003 / 0006 | LOSS 0.1847 | ACCURACY 0.9144
# TRAIN: EPOCH 0044 / 0100 | BATCH 0004 / 0006 | LOSS 0.1856 | ACCURACY 0.9150
# TRAIN: EPOCH 0044 / 0100 | BATCH 0005 / 0006 | LOSS 0.1937 | ACCURACY 0.9121
# TRAIN: EPOCH 0044 / 0100 | BATCH 0006 / 0006 | LOSS 0.1923 | ACCURACY 0.9131
# VALID: EPOCH 0044 / 0100 | BATCH 0001 / 0001 | LOSS 0.1907 | ACCURACY 0.9210
# TRAIN: EPOCH 0045 / 0100 | BATCH 0001 / 0006 | LOSS 0.1943 | ACCURACY 0.9103
# TRAIN: EPOCH 0045 / 0100 | BATCH 0002 / 0006 | LOSS 0.1962 | ACCURACY 0.9057
# TRAIN: EPOCH 0045 / 0100 | BATCH 0003 / 0006 | LOSS 0.1925 | ACCURACY 0.9079
# TRAIN: EPOCH 0045 / 0100 | BATCH 0004 / 0006 | LOSS 0.1956 | ACCURACY 0.9067
# TRAIN: EPOCH 0045 / 0100 | BATCH 0005 / 0006 | LOSS 0.1952 | ACCURACY 0.9074
# TRAIN: EPOCH 0045 / 0100 | BATCH 0006 / 0006 | LOSS 0.1940 | ACCURACY 0.9088
# VALID: EPOCH 0045 / 0100 | BATCH 0001 / 0001 | LOSS 0.1766 | ACCURACY 0.9190
# TRAIN: EPOCH 0046 / 0100 | BATCH 0001 / 0006 | LOSS 0.1897 | ACCURACY 0.9166
# TRAIN: EPOCH 0046 / 0100 | BATCH 0002 / 0006 | LOSS 0.2013 | ACCURACY 0.9100
# TRAIN: EPOCH 0046 / 0100 | BATCH 0003 / 0006 | LOSS 0.1946 | ACCURACY 0.9115
# TRAIN: EPOCH 0046 / 0100 | BATCH 0004 / 0006 | LOSS 0.1955 | ACCURACY 0.9110
# TRAIN: EPOCH 0046 / 0100 | BATCH 0005 / 0006 | LOSS 0.1938 | ACCURACY 0.9109
# TRAIN: EPOCH 0046 / 0100 | BATCH 0006 / 0006 | LOSS 0.1925 | ACCURACY 0.9106
# VALID: EPOCH 0046 / 0100 | BATCH 0001 / 0001 | LOSS 0.1944 | ACCURACY 0.9035
# TRAIN: EPOCH 0047 / 0100 | BATCH 0001 / 0006 | LOSS 0.1748 | ACCURACY 0.9210
# TRAIN: EPOCH 0047 / 0100 | BATCH 0002 / 0006 | LOSS 0.1836 | ACCURACY 0.9173
# TRAIN: EPOCH 0047 / 0100 | BATCH 0003 / 0006 | LOSS 0.1951 | ACCURACY 0.9125
# TRAIN: EPOCH 0047 / 0100 | BATCH 0004 / 0006 | LOSS 0.1924 | ACCURACY 0.9133
# TRAIN: EPOCH 0047 / 0100 | BATCH 0005 / 0006 | LOSS 0.1926 | ACCURACY 0.9132
# TRAIN: EPOCH 0047 / 0100 | BATCH 0006 / 0006 | LOSS 0.1929 | ACCURACY 0.9130
# VALID: EPOCH 0047 / 0100 | BATCH 0001 / 0001 | LOSS 0.1890 | ACCURACY 0.9141
# TRAIN: EPOCH 0048 / 0100 | BATCH 0001 / 0006 | LOSS 0.1916 | ACCURACY 0.9103
# TRAIN: EPOCH 0048 / 0100 | BATCH 0002 / 0006 | LOSS 0.1938 | ACCURACY 0.9082
# TRAIN: EPOCH 0048 / 0100 | BATCH 0003 / 0006 | LOSS 0.1916 | ACCURACY 0.9102
# TRAIN: EPOCH 0048 / 0100 | BATCH 0004 / 0006 | LOSS 0.1959 | ACCURACY 0.9092
# TRAIN: EPOCH 0048 / 0100 | BATCH 0005 / 0006 | LOSS 0.1930 | ACCURACY 0.9107
# TRAIN: EPOCH 0048 / 0100 | BATCH 0006 / 0006 | LOSS 0.1907 | ACCURACY 0.9124
# VALID: EPOCH 0048 / 0100 | BATCH 0001 / 0001 | LOSS 0.1823 | ACCURACY 0.9151
# TRAIN: EPOCH 0049 / 0100 | BATCH 0001 / 0006 | LOSS 0.1898 | ACCURACY 0.9165
# TRAIN: EPOCH 0049 / 0100 | BATCH 0002 / 0006 | LOSS 0.1949 | ACCURACY 0.9153
# TRAIN: EPOCH 0049 / 0100 | BATCH 0003 / 0006 | LOSS 0.1920 | ACCURACY 0.9135
# TRAIN: EPOCH 0049 / 0100 | BATCH 0004 / 0006 | LOSS 0.1880 | ACCURACY 0.9141
# TRAIN: EPOCH 0049 / 0100 | BATCH 0005 / 0006 | LOSS 0.1874 | ACCURACY 0.9135
# TRAIN: EPOCH 0049 / 0100 | BATCH 0006 / 0006 | LOSS 0.1889 | ACCURACY 0.9124
# VALID: EPOCH 0049 / 0100 | BATCH 0001 / 0001 | LOSS 0.1807 | ACCURACY 0.9163
# TRAIN: EPOCH 0050 / 0100 | BATCH 0001 / 0006 | LOSS 0.1934 | ACCURACY 0.9125
# TRAIN: EPOCH 0050 / 0100 | BATCH 0002 / 0006 | LOSS 0.1882 | ACCURACY 0.9167
# TRAIN: EPOCH 0050 / 0100 | BATCH 0003 / 0006 | LOSS 0.1868 | ACCURACY 0.9153
# TRAIN: EPOCH 0050 / 0100 | BATCH 0004 / 0006 | LOSS 0.1888 | ACCURACY 0.9137
# TRAIN: EPOCH 0050 / 0100 | BATCH 0005 / 0006 | LOSS 0.1886 | ACCURACY 0.9144
# TRAIN: EPOCH 0050 / 0100 | BATCH 0006 / 0006 | LOSS 0.1867 | ACCURACY 0.9147
# VALID: EPOCH 0050 / 0100 | BATCH 0001 / 0001 | LOSS 0.1730 | ACCURACY 0.9194
# TRAIN: EPOCH 0051 / 0100 | BATCH 0001 / 0006 | LOSS 0.1885 | ACCURACY 0.9196
# TRAIN: EPOCH 0051 / 0100 | BATCH 0002 / 0006 | LOSS 0.1845 | ACCURACY 0.9175
# TRAIN: EPOCH 0051 / 0100 | BATCH 0003 / 0006 | LOSS 0.1866 | ACCURACY 0.9144
# TRAIN: EPOCH 0051 / 0100 | BATCH 0004 / 0006 | LOSS 0.1886 | ACCURACY 0.9133
# TRAIN: EPOCH 0051 / 0100 | BATCH 0005 / 0006 | LOSS 0.1905 | ACCURACY 0.9123
# TRAIN: EPOCH 0051 / 0100 | BATCH 0006 / 0006 | LOSS 0.1892 | ACCURACY 0.9125
# VALID: EPOCH 0051 / 0100 | BATCH 0001 / 0001 | LOSS 0.1714 | ACCURACY 0.9242
# TRAIN: EPOCH 0052 / 0100 | BATCH 0001 / 0006 | LOSS 0.1868 | ACCURACY 0.9185
# TRAIN: EPOCH 0052 / 0100 | BATCH 0002 / 0006 | LOSS 0.1843 | ACCURACY 0.9173
# TRAIN: EPOCH 0052 / 0100 | BATCH 0003 / 0006 | LOSS 0.1869 | ACCURACY 0.9156
# TRAIN: EPOCH 0052 / 0100 | BATCH 0004 / 0006 | LOSS 0.1882 | ACCURACY 0.9149
# TRAIN: EPOCH 0052 / 0100 | BATCH 0005 / 0006 | LOSS 0.1886 | ACCURACY 0.9145
# TRAIN: EPOCH 0052 / 0100 | BATCH 0006 / 0006 | LOSS 0.1858 | ACCURACY 0.9157
# VALID: EPOCH 0052 / 0100 | BATCH 0001 / 0001 | LOSS 0.1832 | ACCURACY 0.9138
# TRAIN: EPOCH 0053 / 0100 | BATCH 0001 / 0006 | LOSS 0.1957 | ACCURACY 0.9089
# TRAIN: EPOCH 0053 / 0100 | BATCH 0002 / 0006 | LOSS 0.1872 | ACCURACY 0.9124
# TRAIN: EPOCH 0053 / 0100 | BATCH 0003 / 0006 | LOSS 0.1896 | ACCURACY 0.9127
# TRAIN: EPOCH 0053 / 0100 | BATCH 0004 / 0006 | LOSS 0.1871 | ACCURACY 0.9133
# TRAIN: EPOCH 0053 / 0100 | BATCH 0005 / 0006 | LOSS 0.1862 | ACCURACY 0.9138
# TRAIN: EPOCH 0053 / 0100 | BATCH 0006 / 0006 | LOSS 0.1850 | ACCURACY 0.9146
# VALID: EPOCH 0053 / 0100 | BATCH 0001 / 0001 | LOSS 0.1865 | ACCURACY 0.9083
# TRAIN: EPOCH 0054 / 0100 | BATCH 0001 / 0006 | LOSS 0.1927 | ACCURACY 0.9093
# TRAIN: EPOCH 0054 / 0100 | BATCH 0002 / 0006 | LOSS 0.1876 | ACCURACY 0.9114
# TRAIN: EPOCH 0054 / 0100 | BATCH 0003 / 0006 | LOSS 0.1828 | ACCURACY 0.9142
# TRAIN: EPOCH 0054 / 0100 | BATCH 0004 / 0006 | LOSS 0.1833 | ACCURACY 0.9148
# TRAIN: EPOCH 0054 / 0100 | BATCH 0005 / 0006 | LOSS 0.1854 | ACCURACY 0.9151
# TRAIN: EPOCH 0054 / 0100 | BATCH 0006 / 0006 | LOSS 0.1864 | ACCURACY 0.9146
# VALID: EPOCH 0054 / 0100 | BATCH 0001 / 0001 | LOSS 0.1794 | ACCURACY 0.9148
# TRAIN: EPOCH 0055 / 0100 | BATCH 0001 / 0006 | LOSS 0.1903 | ACCURACY 0.9161
# TRAIN: EPOCH 0055 / 0100 | BATCH 0002 / 0006 | LOSS 0.1868 | ACCURACY 0.9141
# TRAIN: EPOCH 0055 / 0100 | BATCH 0003 / 0006 | LOSS 0.1870 | ACCURACY 0.9130
# TRAIN: EPOCH 0055 / 0100 | BATCH 0004 / 0006 | LOSS 0.1865 | ACCURACY 0.9132
# TRAIN: EPOCH 0055 / 0100 | BATCH 0005 / 0006 | LOSS 0.1846 | ACCURACY 0.9140
# TRAIN: EPOCH 0055 / 0100 | BATCH 0006 / 0006 | LOSS 0.1846 | ACCURACY 0.9153
# VALID: EPOCH 0055 / 0100 | BATCH 0001 / 0001 | LOSS 0.1748 | ACCURACY 0.9197
# TRAIN: EPOCH 0056 / 0100 | BATCH 0001 / 0006 | LOSS 0.1822 | ACCURACY 0.9185
# TRAIN: EPOCH 0056 / 0100 | BATCH 0002 / 0006 | LOSS 0.1774 | ACCURACY 0.9204
# TRAIN: EPOCH 0056 / 0100 | BATCH 0003 / 0006 | LOSS 0.1831 | ACCURACY 0.9175
# TRAIN: EPOCH 0056 / 0100 | BATCH 0004 / 0006 | LOSS 0.1804 | ACCURACY 0.9175
# TRAIN: EPOCH 0056 / 0100 | BATCH 0005 / 0006 | LOSS 0.1812 | ACCURACY 0.9172
# TRAIN: EPOCH 0056 / 0100 | BATCH 0006 / 0006 | LOSS 0.1821 | ACCURACY 0.9167
# VALID: EPOCH 0056 / 0100 | BATCH 0001 / 0001 | LOSS 0.1723 | ACCURACY 0.9220
# TRAIN: EPOCH 0057 / 0100 | BATCH 0001 / 0006 | LOSS 0.1756 | ACCURACY 0.9213
# TRAIN: EPOCH 0057 / 0100 | BATCH 0002 / 0006 | LOSS 0.1887 | ACCURACY 0.9165
# TRAIN: EPOCH 0057 / 0100 | BATCH 0003 / 0006 | LOSS 0.1874 | ACCURACY 0.9152
# TRAIN: EPOCH 0057 / 0100 | BATCH 0004 / 0006 | LOSS 0.1856 | ACCURACY 0.9153
# TRAIN: EPOCH 0057 / 0100 | BATCH 0005 / 0006 | LOSS 0.1822 | ACCURACY 0.9163
# TRAIN: EPOCH 0057 / 0100 | BATCH 0006 / 0006 | LOSS 0.1826 | ACCURACY 0.9167
# VALID: EPOCH 0057 / 0100 | BATCH 0001 / 0001 | LOSS 0.1776 | ACCURACY 0.9176
# TRAIN: EPOCH 0058 / 0100 | BATCH 0001 / 0006 | LOSS 0.1956 | ACCURACY 0.9114
# TRAIN: EPOCH 0058 / 0100 | BATCH 0002 / 0006 | LOSS 0.2003 | ACCURACY 0.9102
# TRAIN: EPOCH 0058 / 0100 | BATCH 0003 / 0006 | LOSS 0.1919 | ACCURACY 0.9112
# TRAIN: EPOCH 0058 / 0100 | BATCH 0004 / 0006 | LOSS 0.1866 | ACCURACY 0.9144
# TRAIN: EPOCH 0058 / 0100 | BATCH 0005 / 0006 | LOSS 0.1860 | ACCURACY 0.9146
# TRAIN: EPOCH 0058 / 0100 | BATCH 0006 / 0006 | LOSS 0.1860 | ACCURACY 0.9133
# VALID: EPOCH 0058 / 0100 | BATCH 0001 / 0001 | LOSS 0.1844 | ACCURACY 0.9101
# TRAIN: EPOCH 0059 / 0100 | BATCH 0001 / 0006 | LOSS 0.1888 | ACCURACY 0.9152
# TRAIN: EPOCH 0059 / 0100 | BATCH 0002 / 0006 | LOSS 0.1973 | ACCURACY 0.9115
# TRAIN: EPOCH 0059 / 0100 | BATCH 0003 / 0006 | LOSS 0.1939 | ACCURACY 0.9123
# TRAIN: EPOCH 0059 / 0100 | BATCH 0004 / 0006 | LOSS 0.1985 | ACCURACY 0.9111
# TRAIN: EPOCH 0059 / 0100 | BATCH 0005 / 0006 | LOSS 0.1950 | ACCURACY 0.9113
# TRAIN: EPOCH 0059 / 0100 | BATCH 0006 / 0006 | LOSS 0.1934 | ACCURACY 0.9117
# VALID: EPOCH 0059 / 0100 | BATCH 0001 / 0001 | LOSS 0.1755 | ACCURACY 0.9212
# TRAIN: EPOCH 0060 / 0100 | BATCH 0001 / 0006 | LOSS 0.1849 | ACCURACY 0.9109
# TRAIN: EPOCH 0060 / 0100 | BATCH 0002 / 0006 | LOSS 0.1962 | ACCURACY 0.9105
# TRAIN: EPOCH 0060 / 0100 | BATCH 0003 / 0006 | LOSS 0.1921 | ACCURACY 0.9134
# TRAIN: EPOCH 0060 / 0100 | BATCH 0004 / 0006 | LOSS 0.1909 | ACCURACY 0.9134
# TRAIN: EPOCH 0060 / 0100 | BATCH 0005 / 0006 | LOSS 0.1928 | ACCURACY 0.9118
# TRAIN: EPOCH 0060 / 0100 | BATCH 0006 / 0006 | LOSS 0.1887 | ACCURACY 0.9135
# VALID: EPOCH 0060 / 0100 | BATCH 0001 / 0001 | LOSS 0.1803 | ACCURACY 0.9160
# TRAIN: EPOCH 0061 / 0100 | BATCH 0001 / 0006 | LOSS 0.1897 | ACCURACY 0.9078
# TRAIN: EPOCH 0061 / 0100 | BATCH 0002 / 0006 | LOSS 0.1918 | ACCURACY 0.9087
# TRAIN: EPOCH 0061 / 0100 | BATCH 0003 / 0006 | LOSS 0.1850 | ACCURACY 0.9135
# TRAIN: EPOCH 0061 / 0100 | BATCH 0004 / 0006 | LOSS 0.1889 | ACCURACY 0.9112
# TRAIN: EPOCH 0061 / 0100 | BATCH 0005 / 0006 | LOSS 0.1895 | ACCURACY 0.9121
# TRAIN: EPOCH 0061 / 0100 | BATCH 0006 / 0006 | LOSS 0.1887 | ACCURACY 0.9128
# VALID: EPOCH 0061 / 0100 | BATCH 0001 / 0001 | LOSS 0.1715 | ACCURACY 0.9196
# TRAIN: EPOCH 0062 / 0100 | BATCH 0001 / 0006 | LOSS 0.1876 | ACCURACY 0.9122
# TRAIN: EPOCH 0062 / 0100 | BATCH 0002 / 0006 | LOSS 0.1767 | ACCURACY 0.9158
# TRAIN: EPOCH 0062 / 0100 | BATCH 0003 / 0006 | LOSS 0.1798 | ACCURACY 0.9146
# TRAIN: EPOCH 0062 / 0100 | BATCH 0004 / 0006 | LOSS 0.1787 | ACCURACY 0.9169
# TRAIN: EPOCH 0062 / 0100 | BATCH 0005 / 0006 | LOSS 0.1838 | ACCURACY 0.9153
# TRAIN: EPOCH 0062 / 0100 | BATCH 0006 / 0006 | LOSS 0.1844 | ACCURACY 0.9152
# VALID: EPOCH 0062 / 0100 | BATCH 0001 / 0001 | LOSS 0.1730 | ACCURACY 0.9251
# TRAIN: EPOCH 0063 / 0100 | BATCH 0001 / 0006 | LOSS 0.1854 | ACCURACY 0.9085
# TRAIN: EPOCH 0063 / 0100 | BATCH 0002 / 0006 | LOSS 0.1875 | ACCURACY 0.9108
# TRAIN: EPOCH 0063 / 0100 | BATCH 0003 / 0006 | LOSS 0.1831 | ACCURACY 0.9128
# TRAIN: EPOCH 0063 / 0100 | BATCH 0004 / 0006 | LOSS 0.1870 | ACCURACY 0.9115
# TRAIN: EPOCH 0063 / 0100 | BATCH 0005 / 0006 | LOSS 0.1836 | ACCURACY 0.9134
# TRAIN: EPOCH 0063 / 0100 | BATCH 0006 / 0006 | LOSS 0.1861 | ACCURACY 0.9126
# VALID: EPOCH 0063 / 0100 | BATCH 0001 / 0001 | LOSS 0.1849 | ACCURACY 0.9124
# TRAIN: EPOCH 0064 / 0100 | BATCH 0001 / 0006 | LOSS 0.1813 | ACCURACY 0.9195
# TRAIN: EPOCH 0064 / 0100 | BATCH 0002 / 0006 | LOSS 0.1899 | ACCURACY 0.9147
# TRAIN: EPOCH 0064 / 0100 | BATCH 0003 / 0006 | LOSS 0.1954 | ACCURACY 0.9134
# TRAIN: EPOCH 0064 / 0100 | BATCH 0004 / 0006 | LOSS 0.1898 | ACCURACY 0.9141
# TRAIN: EPOCH 0064 / 0100 | BATCH 0005 / 0006 | LOSS 0.1883 | ACCURACY 0.9132
# TRAIN: EPOCH 0064 / 0100 | BATCH 0006 / 0006 | LOSS 0.1871 | ACCURACY 0.9141
# VALID: EPOCH 0064 / 0100 | BATCH 0001 / 0001 | LOSS 0.1696 | ACCURACY 0.9208
# TRAIN: EPOCH 0065 / 0100 | BATCH 0001 / 0006 | LOSS 0.1865 | ACCURACY 0.9096
# TRAIN: EPOCH 0065 / 0100 | BATCH 0002 / 0006 | LOSS 0.1880 | ACCURACY 0.9115
# TRAIN: EPOCH 0065 / 0100 | BATCH 0003 / 0006 | LOSS 0.1866 | ACCURACY 0.9131
# TRAIN: EPOCH 0065 / 0100 | BATCH 0004 / 0006 | LOSS 0.1865 | ACCURACY 0.9140
# TRAIN: EPOCH 0065 / 0100 | BATCH 0005 / 0006 | LOSS 0.1827 | ACCURACY 0.9156
# TRAIN: EPOCH 0065 / 0100 | BATCH 0006 / 0006 | LOSS 0.1808 | ACCURACY 0.9172
# VALID: EPOCH 0065 / 0100 | BATCH 0001 / 0001 | LOSS 0.1809 | ACCURACY 0.9118
# TRAIN: EPOCH 0066 / 0100 | BATCH 0001 / 0006 | LOSS 0.1725 | ACCURACY 0.9243
# TRAIN: EPOCH 0066 / 0100 | BATCH 0002 / 0006 | LOSS 0.1770 | ACCURACY 0.9219
# TRAIN: EPOCH 0066 / 0100 | BATCH 0003 / 0006 | LOSS 0.1793 | ACCURACY 0.9198
# TRAIN: EPOCH 0066 / 0100 | BATCH 0004 / 0006 | LOSS 0.1786 | ACCURACY 0.9194
# TRAIN: EPOCH 0066 / 0100 | BATCH 0005 / 0006 | LOSS 0.1796 | ACCURACY 0.9177
# TRAIN: EPOCH 0066 / 0100 | BATCH 0006 / 0006 | LOSS 0.1789 | ACCURACY 0.9175
# VALID: EPOCH 0066 / 0100 | BATCH 0001 / 0001 | LOSS 0.1682 | ACCURACY 0.9212
# TRAIN: EPOCH 0067 / 0100 | BATCH 0001 / 0006 | LOSS 0.1748 | ACCURACY 0.9238
# TRAIN: EPOCH 0067 / 0100 | BATCH 0002 / 0006 | LOSS 0.1821 | ACCURACY 0.9188
# TRAIN: EPOCH 0067 / 0100 | BATCH 0003 / 0006 | LOSS 0.1787 | ACCURACY 0.9186
# TRAIN: EPOCH 0067 / 0100 | BATCH 0004 / 0006 | LOSS 0.1794 | ACCURACY 0.9182
# TRAIN: EPOCH 0067 / 0100 | BATCH 0005 / 0006 | LOSS 0.1812 | ACCURACY 0.9179
# TRAIN: EPOCH 0067 / 0100 | BATCH 0006 / 0006 | LOSS 0.1803 | ACCURACY 0.9185
# VALID: EPOCH 0067 / 0100 | BATCH 0001 / 0001 | LOSS 0.1807 | ACCURACY 0.9149
# TRAIN: EPOCH 0068 / 0100 | BATCH 0001 / 0006 | LOSS 0.1800 | ACCURACY 0.9194
# TRAIN: EPOCH 0068 / 0100 | BATCH 0002 / 0006 | LOSS 0.1821 | ACCURACY 0.9179
# TRAIN: EPOCH 0068 / 0100 | BATCH 0003 / 0006 | LOSS 0.1848 | ACCURACY 0.9140
# TRAIN: EPOCH 0068 / 0100 | BATCH 0004 / 0006 | LOSS 0.1833 | ACCURACY 0.9137
# TRAIN: EPOCH 0068 / 0100 | BATCH 0005 / 0006 | LOSS 0.1807 | ACCURACY 0.9155
# TRAIN: EPOCH 0068 / 0100 | BATCH 0006 / 0006 | LOSS 0.1790 | ACCURACY 0.9163
# VALID: EPOCH 0068 / 0100 | BATCH 0001 / 0001 | LOSS 0.1724 | ACCURACY 0.9196
# TRAIN: EPOCH 0069 / 0100 | BATCH 0001 / 0006 | LOSS 0.1640 | ACCURACY 0.9222
# TRAIN: EPOCH 0069 / 0100 | BATCH 0002 / 0006 | LOSS 0.1756 | ACCURACY 0.9180
# TRAIN: EPOCH 0069 / 0100 | BATCH 0003 / 0006 | LOSS 0.1767 | ACCURACY 0.9189
# TRAIN: EPOCH 0069 / 0100 | BATCH 0004 / 0006 | LOSS 0.1775 | ACCURACY 0.9188
# TRAIN: EPOCH 0069 / 0100 | BATCH 0005 / 0006 | LOSS 0.1781 | ACCURACY 0.9191
# TRAIN: EPOCH 0069 / 0100 | BATCH 0006 / 0006 | LOSS 0.1799 | ACCURACY 0.9182
# VALID: EPOCH 0069 / 0100 | BATCH 0001 / 0001 | LOSS 0.1637 | ACCURACY 0.9224
# TRAIN: EPOCH 0070 / 0100 | BATCH 0001 / 0006 | LOSS 0.1942 | ACCURACY 0.9117
# TRAIN: EPOCH 0070 / 0100 | BATCH 0002 / 0006 | LOSS 0.1874 | ACCURACY 0.9118
# TRAIN: EPOCH 0070 / 0100 | BATCH 0003 / 0006 | LOSS 0.1822 | ACCURACY 0.9141
# TRAIN: EPOCH 0070 / 0100 | BATCH 0004 / 0006 | LOSS 0.1815 | ACCURACY 0.9148
# TRAIN: EPOCH 0070 / 0100 | BATCH 0005 / 0006 | LOSS 0.1824 | ACCURACY 0.9147
# TRAIN: EPOCH 0070 / 0100 | BATCH 0006 / 0006 | LOSS 0.1848 | ACCURACY 0.9131
# VALID: EPOCH 0070 / 0100 | BATCH 0001 / 0001 | LOSS 0.1602 | ACCURACY 0.9267
# TRAIN: EPOCH 0071 / 0100 | BATCH 0001 / 0006 | LOSS 0.1703 | ACCURACY 0.9178
# TRAIN: EPOCH 0071 / 0100 | BATCH 0002 / 0006 | LOSS 0.1735 | ACCURACY 0.9168
# TRAIN: EPOCH 0071 / 0100 | BATCH 0003 / 0006 | LOSS 0.1766 | ACCURACY 0.9164
# TRAIN: EPOCH 0071 / 0100 | BATCH 0004 / 0006 | LOSS 0.1744 | ACCURACY 0.9189
# TRAIN: EPOCH 0071 / 0100 | BATCH 0005 / 0006 | LOSS 0.1770 | ACCURACY 0.9184
# TRAIN: EPOCH 0071 / 0100 | BATCH 0006 / 0006 | LOSS 0.1780 | ACCURACY 0.9180
# VALID: EPOCH 0071 / 0100 | BATCH 0001 / 0001 | LOSS 0.1695 | ACCURACY 0.9248
# TRAIN: EPOCH 0072 / 0100 | BATCH 0001 / 0006 | LOSS 0.1772 | ACCURACY 0.9193
# TRAIN: EPOCH 0072 / 0100 | BATCH 0002 / 0006 | LOSS 0.1704 | ACCURACY 0.9229
# TRAIN: EPOCH 0072 / 0100 | BATCH 0003 / 0006 | LOSS 0.1777 | ACCURACY 0.9198
# TRAIN: EPOCH 0072 / 0100 | BATCH 0004 / 0006 | LOSS 0.1770 | ACCURACY 0.9191
# TRAIN: EPOCH 0072 / 0100 | BATCH 0005 / 0006 | LOSS 0.1772 | ACCURACY 0.9186
# TRAIN: EPOCH 0072 / 0100 | BATCH 0006 / 0006 | LOSS 0.1772 | ACCURACY 0.9190
# VALID: EPOCH 0072 / 0100 | BATCH 0001 / 0001 | LOSS 0.1796 | ACCURACY 0.9136
# TRAIN: EPOCH 0073 / 0100 | BATCH 0001 / 0006 | LOSS 0.1673 | ACCURACY 0.9238
# TRAIN: EPOCH 0073 / 0100 | BATCH 0002 / 0006 | LOSS 0.1743 | ACCURACY 0.9204
# TRAIN: EPOCH 0073 / 0100 | BATCH 0003 / 0006 | LOSS 0.1793 | ACCURACY 0.9193
# TRAIN: EPOCH 0073 / 0100 | BATCH 0004 / 0006 | LOSS 0.1770 | ACCURACY 0.9201
# TRAIN: EPOCH 0073 / 0100 | BATCH 0005 / 0006 | LOSS 0.1789 | ACCURACY 0.9191
# TRAIN: EPOCH 0073 / 0100 | BATCH 0006 / 0006 | LOSS 0.1808 | ACCURACY 0.9174
# VALID: EPOCH 0073 / 0100 | BATCH 0001 / 0001 | LOSS 0.1792 | ACCURACY 0.9140
# TRAIN: EPOCH 0074 / 0100 | BATCH 0001 / 0006 | LOSS 0.1951 | ACCURACY 0.9082
# TRAIN: EPOCH 0074 / 0100 | BATCH 0002 / 0006 | LOSS 0.1837 | ACCURACY 0.9121
# TRAIN: EPOCH 0074 / 0100 | BATCH 0003 / 0006 | LOSS 0.1814 | ACCURACY 0.9140
# TRAIN: EPOCH 0074 / 0100 | BATCH 0004 / 0006 | LOSS 0.1794 | ACCURACY 0.9157
# TRAIN: EPOCH 0074 / 0100 | BATCH 0005 / 0006 | LOSS 0.1830 | ACCURACY 0.9158
# TRAIN: EPOCH 0074 / 0100 | BATCH 0006 / 0006 | LOSS 0.1854 | ACCURACY 0.9146
# VALID: EPOCH 0074 / 0100 | BATCH 0001 / 0001 | LOSS 0.1678 | ACCURACY 0.9226
# TRAIN: EPOCH 0075 / 0100 | BATCH 0001 / 0006 | LOSS 0.1713 | ACCURACY 0.9197
# TRAIN: EPOCH 0075 / 0100 | BATCH 0002 / 0006 | LOSS 0.1891 | ACCURACY 0.9109
# TRAIN: EPOCH 0075 / 0100 | BATCH 0003 / 0006 | LOSS 0.1879 | ACCURACY 0.9126
# TRAIN: EPOCH 0075 / 0100 | BATCH 0004 / 0006 | LOSS 0.1840 | ACCURACY 0.9147
# TRAIN: EPOCH 0075 / 0100 | BATCH 0005 / 0006 | LOSS 0.1837 | ACCURACY 0.9145
# TRAIN: EPOCH 0075 / 0100 | BATCH 0006 / 0006 | LOSS 0.1874 | ACCURACY 0.9136
# VALID: EPOCH 0075 / 0100 | BATCH 0001 / 0001 | LOSS 0.1799 | ACCURACY 0.9103
# TRAIN: EPOCH 0076 / 0100 | BATCH 0001 / 0006 | LOSS 0.1804 | ACCURACY 0.9180
# TRAIN: EPOCH 0076 / 0100 | BATCH 0002 / 0006 | LOSS 0.1809 | ACCURACY 0.9166
# TRAIN: EPOCH 0076 / 0100 | BATCH 0003 / 0006 | LOSS 0.1824 | ACCURACY 0.9157
# TRAIN: EPOCH 0076 / 0100 | BATCH 0004 / 0006 | LOSS 0.1841 | ACCURACY 0.9165
# TRAIN: EPOCH 0076 / 0100 | BATCH 0005 / 0006 | LOSS 0.1861 | ACCURACY 0.9158
# TRAIN: EPOCH 0076 / 0100 | BATCH 0006 / 0006 | LOSS 0.1835 | ACCURACY 0.9168
# VALID: EPOCH 0076 / 0100 | BATCH 0001 / 0001 | LOSS 0.1757 | ACCURACY 0.9205
# TRAIN: EPOCH 0077 / 0100 | BATCH 0001 / 0006 | LOSS 0.1819 | ACCURACY 0.9156
# TRAIN: EPOCH 0077 / 0100 | BATCH 0002 / 0006 | LOSS 0.1801 | ACCURACY 0.9157
# TRAIN: EPOCH 0077 / 0100 | BATCH 0003 / 0006 | LOSS 0.1805 | ACCURACY 0.9149
# TRAIN: EPOCH 0077 / 0100 | BATCH 0004 / 0006 | LOSS 0.1806 | ACCURACY 0.9155
# TRAIN: EPOCH 0077 / 0100 | BATCH 0005 / 0006 | LOSS 0.1814 | ACCURACY 0.9155
# TRAIN: EPOCH 0077 / 0100 | BATCH 0006 / 0006 | LOSS 0.1791 | ACCURACY 0.9172
# VALID: EPOCH 0077 / 0100 | BATCH 0001 / 0001 | LOSS 0.1672 | ACCURACY 0.9220
# TRAIN: EPOCH 0078 / 0100 | BATCH 0001 / 0006 | LOSS 0.1786 | ACCURACY 0.9195
# TRAIN: EPOCH 0078 / 0100 | BATCH 0002 / 0006 | LOSS 0.1777 | ACCURACY 0.9185
# TRAIN: EPOCH 0078 / 0100 | BATCH 0003 / 0006 | LOSS 0.1794 | ACCURACY 0.9181
# TRAIN: EPOCH 0078 / 0100 | BATCH 0004 / 0006 | LOSS 0.1766 | ACCURACY 0.9190
# TRAIN: EPOCH 0078 / 0100 | BATCH 0005 / 0006 | LOSS 0.1770 | ACCURACY 0.9187
# TRAIN: EPOCH 0078 / 0100 | BATCH 0006 / 0006 | LOSS 0.1787 | ACCURACY 0.9182
# VALID: EPOCH 0078 / 0100 | BATCH 0001 / 0001 | LOSS 0.1684 | ACCURACY 0.9223
# TRAIN: EPOCH 0079 / 0100 | BATCH 0001 / 0006 | LOSS 0.1675 | ACCURACY 0.9230
# TRAIN: EPOCH 0079 / 0100 | BATCH 0002 / 0006 | LOSS 0.1764 | ACCURACY 0.9186
# TRAIN: EPOCH 0079 / 0100 | BATCH 0003 / 0006 | LOSS 0.1795 | ACCURACY 0.9150
# TRAIN: EPOCH 0079 / 0100 | BATCH 0004 / 0006 | LOSS 0.1817 | ACCURACY 0.9147
# TRAIN: EPOCH 0079 / 0100 | BATCH 0005 / 0006 | LOSS 0.1780 | ACCURACY 0.9172
# TRAIN: EPOCH 0079 / 0100 | BATCH 0006 / 0006 | LOSS 0.1820 | ACCURACY 0.9156
# VALID: EPOCH 0079 / 0100 | BATCH 0001 / 0001 | LOSS 0.1679 | ACCURACY 0.9192
# TRAIN: EPOCH 0080 / 0100 | BATCH 0001 / 0006 | LOSS 0.1752 | ACCURACY 0.9185
# TRAIN: EPOCH 0080 / 0100 | BATCH 0002 / 0006 | LOSS 0.1817 | ACCURACY 0.9151
# TRAIN: EPOCH 0080 / 0100 | BATCH 0003 / 0006 | LOSS 0.1785 | ACCURACY 0.9166
# TRAIN: EPOCH 0080 / 0100 | BATCH 0004 / 0006 | LOSS 0.1808 | ACCURACY 0.9153
# TRAIN: EPOCH 0080 / 0100 | BATCH 0005 / 0006 | LOSS 0.1787 | ACCURACY 0.9167
# TRAIN: EPOCH 0080 / 0100 | BATCH 0006 / 0006 | LOSS 0.1782 | ACCURACY 0.9177
# VALID: EPOCH 0080 / 0100 | BATCH 0001 / 0001 | LOSS 0.1700 | ACCURACY 0.9198
# TRAIN: EPOCH 0081 / 0100 | BATCH 0001 / 0006 | LOSS 0.1675 | ACCURACY 0.9197
# TRAIN: EPOCH 0081 / 0100 | BATCH 0002 / 0006 | LOSS 0.1699 | ACCURACY 0.9202
# TRAIN: EPOCH 0081 / 0100 | BATCH 0003 / 0006 | LOSS 0.1737 | ACCURACY 0.9202
# TRAIN: EPOCH 0081 / 0100 | BATCH 0004 / 0006 | LOSS 0.1810 | ACCURACY 0.9172
# TRAIN: EPOCH 0081 / 0100 | BATCH 0005 / 0006 | LOSS 0.1792 | ACCURACY 0.9179
# TRAIN: EPOCH 0081 / 0100 | BATCH 0006 / 0006 | LOSS 0.1785 | ACCURACY 0.9186
# VALID: EPOCH 0081 / 0100 | BATCH 0001 / 0001 | LOSS 0.1654 | ACCURACY 0.9236
# TRAIN: EPOCH 0082 / 0100 | BATCH 0001 / 0006 | LOSS 0.1706 | ACCURACY 0.9204
# TRAIN: EPOCH 0082 / 0100 | BATCH 0002 / 0006 | LOSS 0.1757 | ACCURACY 0.9189
# TRAIN: EPOCH 0082 / 0100 | BATCH 0003 / 0006 | LOSS 0.1755 | ACCURACY 0.9175
# TRAIN: EPOCH 0082 / 0100 | BATCH 0004 / 0006 | LOSS 0.1757 | ACCURACY 0.9185
# TRAIN: EPOCH 0082 / 0100 | BATCH 0005 / 0006 | LOSS 0.1768 | ACCURACY 0.9182
# TRAIN: EPOCH 0082 / 0100 | BATCH 0006 / 0006 | LOSS 0.1748 | ACCURACY 0.9181
# VALID: EPOCH 0082 / 0100 | BATCH 0001 / 0001 | LOSS 0.1699 | ACCURACY 0.9221
# TRAIN: EPOCH 0083 / 0100 | BATCH 0001 / 0006 | LOSS 0.1834 | ACCURACY 0.9144
# TRAIN: EPOCH 0083 / 0100 | BATCH 0002 / 0006 | LOSS 0.1768 | ACCURACY 0.9182
# TRAIN: EPOCH 0083 / 0100 | BATCH 0003 / 0006 | LOSS 0.1831 | ACCURACY 0.9156
# TRAIN: EPOCH 0083 / 0100 | BATCH 0004 / 0006 | LOSS 0.1812 | ACCURACY 0.9164
# TRAIN: EPOCH 0083 / 0100 | BATCH 0005 / 0006 | LOSS 0.1788 | ACCURACY 0.9178
# TRAIN: EPOCH 0083 / 0100 | BATCH 0006 / 0006 | LOSS 0.1771 | ACCURACY 0.9190
# VALID: EPOCH 0083 / 0100 | BATCH 0001 / 0001 | LOSS 0.1834 | ACCURACY 0.9113
# TRAIN: EPOCH 0084 / 0100 | BATCH 0001 / 0006 | LOSS 0.1636 | ACCURACY 0.9261
# TRAIN: EPOCH 0084 / 0100 | BATCH 0002 / 0006 | LOSS 0.1637 | ACCURACY 0.9256
# TRAIN: EPOCH 0084 / 0100 | BATCH 0003 / 0006 | LOSS 0.1677 | ACCURACY 0.9243
# TRAIN: EPOCH 0084 / 0100 | BATCH 0004 / 0006 | LOSS 0.1710 | ACCURACY 0.9227
# TRAIN: EPOCH 0084 / 0100 | BATCH 0005 / 0006 | LOSS 0.1733 | ACCURACY 0.9210
# TRAIN: EPOCH 0084 / 0100 | BATCH 0006 / 0006 | LOSS 0.1727 | ACCURACY 0.9208
# VALID: EPOCH 0084 / 0100 | BATCH 0001 / 0001 | LOSS 0.1659 | ACCURACY 0.9209
# TRAIN: EPOCH 0085 / 0100 | BATCH 0001 / 0006 | LOSS 0.1828 | ACCURACY 0.9107
# TRAIN: EPOCH 0085 / 0100 | BATCH 0002 / 0006 | LOSS 0.1773 | ACCURACY 0.9155
# TRAIN: EPOCH 0085 / 0100 | BATCH 0003 / 0006 | LOSS 0.1783 | ACCURACY 0.9160
# TRAIN: EPOCH 0085 / 0100 | BATCH 0004 / 0006 | LOSS 0.1726 | ACCURACY 0.9186
# TRAIN: EPOCH 0085 / 0100 | BATCH 0005 / 0006 | LOSS 0.1731 | ACCURACY 0.9188
# TRAIN: EPOCH 0085 / 0100 | BATCH 0006 / 0006 | LOSS 0.1760 | ACCURACY 0.9183
# VALID: EPOCH 0085 / 0100 | BATCH 0001 / 0001 | LOSS 0.1663 | ACCURACY 0.9214
# TRAIN: EPOCH 0086 / 0100 | BATCH 0001 / 0006 | LOSS 0.1893 | ACCURACY 0.9131
# TRAIN: EPOCH 0086 / 0100 | BATCH 0002 / 0006 | LOSS 0.1788 | ACCURACY 0.9145
# TRAIN: EPOCH 0086 / 0100 | BATCH 0003 / 0006 | LOSS 0.1795 | ACCURACY 0.9143
# TRAIN: EPOCH 0086 / 0100 | BATCH 0004 / 0006 | LOSS 0.1774 | ACCURACY 0.9167
# TRAIN: EPOCH 0086 / 0100 | BATCH 0005 / 0006 | LOSS 0.1743 | ACCURACY 0.9182
# TRAIN: EPOCH 0086 / 0100 | BATCH 0006 / 0006 | LOSS 0.1736 | ACCURACY 0.9182
# VALID: EPOCH 0086 / 0100 | BATCH 0001 / 0001 | LOSS 0.1680 | ACCURACY 0.9182
# TRAIN: EPOCH 0087 / 0100 | BATCH 0001 / 0006 | LOSS 0.1796 | ACCURACY 0.9170
# TRAIN: EPOCH 0087 / 0100 | BATCH 0002 / 0006 | LOSS 0.1826 | ACCURACY 0.9167
# TRAIN: EPOCH 0087 / 0100 | BATCH 0003 / 0006 | LOSS 0.1782 | ACCURACY 0.9174
# TRAIN: EPOCH 0087 / 0100 | BATCH 0004 / 0006 | LOSS 0.1784 | ACCURACY 0.9175
# TRAIN: EPOCH 0087 / 0100 | BATCH 0005 / 0006 | LOSS 0.1781 | ACCURACY 0.9175
# TRAIN: EPOCH 0087 / 0100 | BATCH 0006 / 0006 | LOSS 0.1775 | ACCURACY 0.9180
# VALID: EPOCH 0087 / 0100 | BATCH 0001 / 0001 | LOSS 0.1754 | ACCURACY 0.9204
# TRAIN: EPOCH 0088 / 0100 | BATCH 0001 / 0006 | LOSS 0.1654 | ACCURACY 0.9221
# TRAIN: EPOCH 0088 / 0100 | BATCH 0002 / 0006 | LOSS 0.1668 | ACCURACY 0.9235
# TRAIN: EPOCH 0088 / 0100 | BATCH 0003 / 0006 | LOSS 0.1722 | ACCURACY 0.9212
# TRAIN: EPOCH 0088 / 0100 | BATCH 0004 / 0006 | LOSS 0.1715 | ACCURACY 0.9220
# TRAIN: EPOCH 0088 / 0100 | BATCH 0005 / 0006 | LOSS 0.1739 | ACCURACY 0.9204
# TRAIN: EPOCH 0088 / 0100 | BATCH 0006 / 0006 | LOSS 0.1752 | ACCURACY 0.9199
# VALID: EPOCH 0088 / 0100 | BATCH 0001 / 0001 | LOSS 0.1782 | ACCURACY 0.9209
# TRAIN: EPOCH 0089 / 0100 | BATCH 0001 / 0006 | LOSS 0.1749 | ACCURACY 0.9184
# TRAIN: EPOCH 0089 / 0100 | BATCH 0002 / 0006 | LOSS 0.1695 | ACCURACY 0.9200
# TRAIN: EPOCH 0089 / 0100 | BATCH 0003 / 0006 | LOSS 0.1706 | ACCURACY 0.9203
# TRAIN: EPOCH 0089 / 0100 | BATCH 0004 / 0006 | LOSS 0.1714 | ACCURACY 0.9204
# TRAIN: EPOCH 0089 / 0100 | BATCH 0005 / 0006 | LOSS 0.1736 | ACCURACY 0.9201
# TRAIN: EPOCH 0089 / 0100 | BATCH 0006 / 0006 | LOSS 0.1746 | ACCURACY 0.9192
# VALID: EPOCH 0089 / 0100 | BATCH 0001 / 0001 | LOSS 0.1667 | ACCURACY 0.9258
# TRAIN: EPOCH 0090 / 0100 | BATCH 0001 / 0006 | LOSS 0.1663 | ACCURACY 0.9200
# TRAIN: EPOCH 0090 / 0100 | BATCH 0002 / 0006 | LOSS 0.1668 | ACCURACY 0.9230
# TRAIN: EPOCH 0090 / 0100 | BATCH 0003 / 0006 | LOSS 0.1673 | ACCURACY 0.9228
# TRAIN: EPOCH 0090 / 0100 | BATCH 0004 / 0006 | LOSS 0.1683 | ACCURACY 0.9227
# TRAIN: EPOCH 0090 / 0100 | BATCH 0005 / 0006 | LOSS 0.1724 | ACCURACY 0.9215
# TRAIN: EPOCH 0090 / 0100 | BATCH 0006 / 0006 | LOSS 0.1728 | ACCURACY 0.9205
# VALID: EPOCH 0090 / 0100 | BATCH 0001 / 0001 | LOSS 0.1697 | ACCURACY 0.9222
# TRAIN: EPOCH 0091 / 0100 | BATCH 0001 / 0006 | LOSS 0.1757 | ACCURACY 0.9181
# TRAIN: EPOCH 0091 / 0100 | BATCH 0002 / 0006 | LOSS 0.1808 | ACCURACY 0.9168
# TRAIN: EPOCH 0091 / 0100 | BATCH 0003 / 0006 | LOSS 0.1790 | ACCURACY 0.9188
# TRAIN: EPOCH 0091 / 0100 | BATCH 0004 / 0006 | LOSS 0.1772 | ACCURACY 0.9191
# TRAIN: EPOCH 0091 / 0100 | BATCH 0005 / 0006 | LOSS 0.1760 | ACCURACY 0.9200
# TRAIN: EPOCH 0091 / 0100 | BATCH 0006 / 0006 | LOSS 0.1780 | ACCURACY 0.9185
# VALID: EPOCH 0091 / 0100 | BATCH 0001 / 0001 | LOSS 0.1701 | ACCURACY 0.9197
# TRAIN: EPOCH 0092 / 0100 | BATCH 0001 / 0006 | LOSS 0.1783 | ACCURACY 0.9227
# TRAIN: EPOCH 0092 / 0100 | BATCH 0002 / 0006 | LOSS 0.1776 | ACCURACY 0.9209
# TRAIN: EPOCH 0092 / 0100 | BATCH 0003 / 0006 | LOSS 0.1794 | ACCURACY 0.9183
# TRAIN: EPOCH 0092 / 0100 | BATCH 0004 / 0006 | LOSS 0.1795 | ACCURACY 0.9169
# TRAIN: EPOCH 0092 / 0100 | BATCH 0005 / 0006 | LOSS 0.1791 | ACCURACY 0.9163
# TRAIN: EPOCH 0092 / 0100 | BATCH 0006 / 0006 | LOSS 0.1771 | ACCURACY 0.9174
# VALID: EPOCH 0092 / 0100 | BATCH 0001 / 0001 | LOSS 0.1726 | ACCURACY 0.9187
# TRAIN: EPOCH 0093 / 0100 | BATCH 0001 / 0006 | LOSS 0.1923 | ACCURACY 0.9152
# TRAIN: EPOCH 0093 / 0100 | BATCH 0002 / 0006 | LOSS 0.1818 | ACCURACY 0.9175
# TRAIN: EPOCH 0093 / 0100 | BATCH 0003 / 0006 | LOSS 0.1791 | ACCURACY 0.9183
# TRAIN: EPOCH 0093 / 0100 | BATCH 0004 / 0006 | LOSS 0.1743 | ACCURACY 0.9210
# TRAIN: EPOCH 0093 / 0100 | BATCH 0005 / 0006 | LOSS 0.1762 | ACCURACY 0.9199
# TRAIN: EPOCH 0093 / 0100 | BATCH 0006 / 0006 | LOSS 0.1757 | ACCURACY 0.9194
# VALID: EPOCH 0093 / 0100 | BATCH 0001 / 0001 | LOSS 0.1798 | ACCURACY 0.9139
# TRAIN: EPOCH 0094 / 0100 | BATCH 0001 / 0006 | LOSS 0.1806 | ACCURACY 0.9161
# TRAIN: EPOCH 0094 / 0100 | BATCH 0002 / 0006 | LOSS 0.1843 | ACCURACY 0.9154
# TRAIN: EPOCH 0094 / 0100 | BATCH 0003 / 0006 | LOSS 0.1795 | ACCURACY 0.9176
# TRAIN: EPOCH 0094 / 0100 | BATCH 0004 / 0006 | LOSS 0.1773 | ACCURACY 0.9169
# TRAIN: EPOCH 0094 / 0100 | BATCH 0005 / 0006 | LOSS 0.1749 | ACCURACY 0.9184
# TRAIN: EPOCH 0094 / 0100 | BATCH 0006 / 0006 | LOSS 0.1744 | ACCURACY 0.9190
# VALID: EPOCH 0094 / 0100 | BATCH 0001 / 0001 | LOSS 0.1833 | ACCURACY 0.9137
# TRAIN: EPOCH 0095 / 0100 | BATCH 0001 / 0006 | LOSS 0.1794 | ACCURACY 0.9181
# TRAIN: EPOCH 0095 / 0100 | BATCH 0002 / 0006 | LOSS 0.1797 | ACCURACY 0.9191
# TRAIN: EPOCH 0095 / 0100 | BATCH 0003 / 0006 | LOSS 0.1758 | ACCURACY 0.9194
# TRAIN: EPOCH 0095 / 0100 | BATCH 0004 / 0006 | LOSS 0.1774 | ACCURACY 0.9189
# TRAIN: EPOCH 0095 / 0100 | BATCH 0005 / 0006 | LOSS 0.1789 | ACCURACY 0.9175
# TRAIN: EPOCH 0095 / 0100 | BATCH 0006 / 0006 | LOSS 0.1777 | ACCURACY 0.9184
# VALID: EPOCH 0095 / 0100 | BATCH 0001 / 0001 | LOSS 0.1774 | ACCURACY 0.9178
# TRAIN: EPOCH 0096 / 0100 | BATCH 0001 / 0006 | LOSS 0.1735 | ACCURACY 0.9216
# TRAIN: EPOCH 0096 / 0100 | BATCH 0002 / 0006 | LOSS 0.1782 | ACCURACY 0.9194
# TRAIN: EPOCH 0096 / 0100 | BATCH 0003 / 0006 | LOSS 0.1762 | ACCURACY 0.9185
# TRAIN: EPOCH 0096 / 0100 | BATCH 0004 / 0006 | LOSS 0.1742 | ACCURACY 0.9190
# TRAIN: EPOCH 0096 / 0100 | BATCH 0005 / 0006 | LOSS 0.1754 | ACCURACY 0.9190
# TRAIN: EPOCH 0096 / 0100 | BATCH 0006 / 0006 | LOSS 0.1746 | ACCURACY 0.9199
# VALID: EPOCH 0096 / 0100 | BATCH 0001 / 0001 | LOSS 0.1644 | ACCURACY 0.9235
# TRAIN: EPOCH 0097 / 0100 | BATCH 0001 / 0006 | LOSS 0.1631 | ACCURACY 0.9229
# TRAIN: EPOCH 0097 / 0100 | BATCH 0002 / 0006 | LOSS 0.1724 | ACCURACY 0.9192
# TRAIN: EPOCH 0097 / 0100 | BATCH 0003 / 0006 | LOSS 0.1770 | ACCURACY 0.9160
# TRAIN: EPOCH 0097 / 0100 | BATCH 0004 / 0006 | LOSS 0.1762 | ACCURACY 0.9167
# TRAIN: EPOCH 0097 / 0100 | BATCH 0005 / 0006 | LOSS 0.1755 | ACCURACY 0.9178
# TRAIN: EPOCH 0097 / 0100 | BATCH 0006 / 0006 | LOSS 0.1733 | ACCURACY 0.9187
# VALID: EPOCH 0097 / 0100 | BATCH 0001 / 0001 | LOSS 0.1733 | ACCURACY 0.9169
# TRAIN: EPOCH 0098 / 0100 | BATCH 0001 / 0006 | LOSS 0.1623 | ACCURACY 0.9204
# TRAIN: EPOCH 0098 / 0100 | BATCH 0002 / 0006 | LOSS 0.1639 | ACCURACY 0.9233
# TRAIN: EPOCH 0098 / 0100 | BATCH 0003 / 0006 | LOSS 0.1641 | ACCURACY 0.9250
# TRAIN: EPOCH 0098 / 0100 | BATCH 0004 / 0006 | LOSS 0.1713 | ACCURACY 0.9231
# TRAIN: EPOCH 0098 / 0100 | BATCH 0005 / 0006 | LOSS 0.1708 | ACCURACY 0.9229
# TRAIN: EPOCH 0098 / 0100 | BATCH 0006 / 0006 | LOSS 0.1736 | ACCURACY 0.9213
# VALID: EPOCH 0098 / 0100 | BATCH 0001 / 0001 | LOSS 0.1700 | ACCURACY 0.9224
# TRAIN: EPOCH 0099 / 0100 | BATCH 0001 / 0006 | LOSS 0.1770 | ACCURACY 0.9189
# TRAIN: EPOCH 0099 / 0100 | BATCH 0002 / 0006 | LOSS 0.1708 | ACCURACY 0.9189
# TRAIN: EPOCH 0099 / 0100 | BATCH 0003 / 0006 | LOSS 0.1705 | ACCURACY 0.9176
# TRAIN: EPOCH 0099 / 0100 | BATCH 0004 / 0006 | LOSS 0.1703 | ACCURACY 0.9182
# TRAIN: EPOCH 0099 / 0100 | BATCH 0005 / 0006 | LOSS 0.1737 | ACCURACY 0.9171
# TRAIN: EPOCH 0099 / 0100 | BATCH 0006 / 0006 | LOSS 0.1718 | ACCURACY 0.9184
# VALID: EPOCH 0099 / 0100 | BATCH 0001 / 0001 | LOSS 0.1680 | ACCURACY 0.9216
# TRAIN: EPOCH 0100 / 0100 | BATCH 0001 / 0006 | LOSS 0.1702 | ACCURACY 0.9236
# TRAIN: EPOCH 0100 / 0100 | BATCH 0002 / 0006 | LOSS 0.1765 | ACCURACY 0.9212
# TRAIN: EPOCH 0100 / 0100 | BATCH 0003 / 0006 | LOSS 0.1762 | ACCURACY 0.9196
# TRAIN: EPOCH 0100 / 0100 | BATCH 0004 / 0006 | LOSS 0.1744 | ACCURACY 0.9205
# TRAIN: EPOCH 0100 / 0100 | BATCH 0005 / 0006 | LOSS 0.1758 | ACCURACY 0.9204
# TRAIN: EPOCH 0100 / 0100 | BATCH 0006 / 0006 | LOSS 0.1751 | ACCURACY 0.9202
# VALID: EPOCH 0100 / 0100 | BATCH 0001 / 0001 | LOSS 0.1636 | ACCURACY 0.9271

# %% [markdown]
# ## 5. Test
#
# 학습이 모두 끝났다면, 가장 낮은 validation loss를 기록한 모델의 파라미터를 불러오도록 합시다.
#
# 이후에는 accuracy 등을 측정하여 모델이 얼마나 잘 학습되었는지 평가하도록 하겠습니다.

# %% [markdown]
# ### 문제 5.
#
# accuracy 90% 이상이 되도록 학습률 에포크 등의 하이퍼파라미터를 조절해주세요.
# 학습의 결과를 캡쳐하여 하단에 첨부해주세요.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [풀이]

# %%
transform = transforms.Compose([Normalization(mean=0.5, std=0.5), ToTensor()])

dataset_test = Dataset(data_dir=os.path.join(data_dir, 'test'), transform=transform)
loader_test = DataLoader(dataset_test, batch_size=batch_size, shuffle=False, num_workers=8)

# 그밖에 부수적인 variables 설정하기
num_data_test = len(dataset_test)
num_batch_test = np.ceil(num_data_test / batch_size)

# 결과 디렉토리 생성하기
result_dir = os.path.join(base_dir, 'result')
if not os.path.exists(result_dir):
    os.makedirs(os.path.join(result_dir, 'png'))
    os.makedirs(os.path.join(result_dir, 'numpy'))


net, optim, st_epoch = load(ckpt_dir=ckpt_dir, net=net, optim=optim)
# 테스트 수행하기
with torch.no_grad():
    net.eval()
    loss_arr = []
    accuracy_arr = []

    for batch, data in enumerate(loader_test, 1):
        # forward pass
        label = data['label'].to(device)
        input = data['input'].to(device)

        output = net(input)

        # 손실 함수 계산하기
        loss = fn_loss(output, label)
        loss_arr.append(loss.item())

        # 정확도 계산하기
        acc = compute_accuracy(output, label)
        accuracy_arr.append(acc)

        print("TEST: BATCH %04d / %04d | LOSS %.4f | ACCURACY %.4f" %
              (batch, num_batch_test, np.mean(loss_arr), np.mean(accuracy_arr)))

        # 결과 저장하기
        label = fn_tonumpy(label)
        input = fn_tonumpy(fn_denorm(input, mean=0.5, std=0.5))
        output = fn_tonumpy(fn_class(output))

        for j in range(label.shape[0]):
            id = num_batch_test * (batch - 1) + j

            plt.imsave(os.path.join(result_dir, 'png', 'label_%04d.png' % id), label[j].squeeze(), cmap='gray')
            plt.imsave(os.path.join(result_dir, 'png', 'input_%04d.png' % id), input[j].squeeze(), cmap='gray')
            plt.imsave(os.path.join(result_dir, 'png', 'output_%04d.png' % id), output[j].squeeze(), cmap='gray')

            np.save(os.path.join(result_dir, 'numpy', 'label_%04d.npy' % id), label[j].squeeze())
            np.save(os.path.join(result_dir, 'numpy', 'input_%04d.npy' % id), input[j].squeeze())
            np.save(os.path.join(result_dir, 'numpy', 'output_%04d.npy' % id), output[j].squeeze())

    # 평균 손실과 정확도 출력
    avg_loss = np.mean(loss_arr)
    avg_accuracy = np.mean(accuracy_arr)
    print("AVERAGE TEST: BATCH %04d / %04d | LOSS %.4f | ACCURACY %.4f" %
          (batch, num_batch_test, avg_loss, avg_accuracy))
# Out:
# TEST: BATCH 0001 / 0001 | LOSS 0.1947 | ACCURACY 0.9133
# AVERAGE TEST: BATCH 0001 / 0001 | LOSS 0.1947 | ACCURACY 0.9133

# %%
######  결과를 확인해보세요!  ######
lst_data = os.listdir(os.path.join(result_dir, 'numpy'))

lst_label = [f for f in lst_data if f.startswith('label')]
lst_input = [f for f in lst_data if f.startswith('input')]
lst_output = [f for f in lst_data if f.startswith('output')]

lst_label.sort()
lst_input.sort()
lst_output.sort()

##
id = 0

label = np.load(os.path.join(result_dir,"numpy", lst_label[id]))
input = np.load(os.path.join(result_dir,"numpy", lst_input[id]))
output = np.load(os.path.join(result_dir,"numpy", lst_output[id]))

## 플롯 그리기
plt.figure(figsize=(8,6))
plt.subplot(131)
plt.imshow(input, cmap='gray')
plt.title('input')

plt.subplot(132)
plt.imshow(label, cmap='gray')
plt.title('label')

plt.subplot(133)
plt.imshow(output, cmap='gray')
plt.title('output')

plt.show()

# %% [markdown]
# ### 문제 6.
#
# U-Net의 논문과 코드 모두를 살펴보았습니다. 해당 과제를 수행하면서 알게 된 U-Net의 특징을 1) 모델 설계 의도 2) 구조적 특징 3) 손실함수 및 데이터 증강기법으로 나누어 서술해주세요.

# %% [markdown]
# [풀이]
#
# 1. U-Net은 주로 생물의학 이미지 분할에 사용되므로, 특정 개체를 이미지 내에서 정확히 분리해내는 것이 핵심입니다. 정확한 개체 검출과 소규모 데이터로도 효율적으로 학습할 수 있도록 설계하였습니다.
# 2. U-Net의 구조는 크게 contracting path와 expansive path로 나뉩니다.
# 3. 손실 함수로는 cross entropy loss에 weight를 곱했으며, elastic deformation 기법으로 데이터 증강을 하였습니다.

# %% [markdown]
# 수고 많으셨습니다 !!

# %% [markdown]
# References:\
# 10기 윤형진 CNN 과제
